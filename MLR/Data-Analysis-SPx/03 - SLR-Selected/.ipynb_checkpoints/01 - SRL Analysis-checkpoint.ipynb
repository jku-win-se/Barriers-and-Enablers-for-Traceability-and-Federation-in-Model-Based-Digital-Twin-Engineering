# %% [markdown]
# # Multivocal Literature Review - Systematic Literature Review Data Analysis
# This notebook shows how to use litstudy from inside a Jupyter notebook. It shows how to load a dataset, plot statistics, perform topic modeling, do network analysis, and some more advanced features.
#
# This notebook focuses on the topic of federated DT.
#
# # Imports Selected Studies

# %%
# Import other libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs
import re

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
from datetime import datetime

currentDateAndTime = datetime.now()
filename = (f'MLR_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}')
filename_xlsx = (f'MLR_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}.xlsx')

print(filename)
# Out:
# MLR_2025-1-8_20-22-20

# %%
############################## LOAD Cleaned papers ###################################

# with open('AAA/studies.txt', 'r') as file:
#     data = file.read().splitlines()
#     print(data)
    
# Load csv file
docs_bib = litstudy.load_scopus_csv('Results/Selected.csv')
print(len(docs_bib), 'papers loaded from selected papers list')
# Out:
# 23 papers loaded from selected papers list

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)

docs_found_scopus, docs_notfound_scopus = litstudy.refine_scopus(docs_bib)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 import logging
#       2 logging.getLogger().setLevel(logging.CRITICAL)
# ----> 4 docs_found_scopus, docs_notfound_scopus = litstudy.refine_scopus(docs_bib)
#
# File ~\anaconda3\lib\site-packages\litstudy\sources\scopus.py:248, in refine_scopus(docs, search_title)
#     244                     return ScopusDocument.from_eid(record.eid)
#     246     return None
# --> 248 return docs._refine_docs(callback)
#
# File ~\anaconda3\lib\site-packages\litstudy\types.py:53, in DocumentSet._refine_docs(self, callback)
#      50 old_docs = []
#      52 for i, doc in enumerate(progress_bar(self.docs)):
# ---> 53     new_doc = callback(doc)
#      55     if new_doc is not None:
#      56         new_indices.append(i)
#
# File ~\anaconda3\lib\site-packages\litstudy\sources\scopus.py:233, in refine_scopus.<locals>.callback(doc)
#     230         logging.warn(f"no document found for DOI {doi}: {e}")
#     231         return None
# --> 233 title = canonical(id.title)
#     234 if len(title) > 10 and search_title:
#     235     query = f"TITLE({title})"
#
# File ~\anaconda3\lib\site-packages\litstudy\common.py:45, in canonical(key, aggresive, stopwords)
#      42     stopwords = STOPWORDS
#      44 if aggresive:
# ---> 45     key = unidecode(key).lower()
#      47 tokens = re.split(r"[\W]+", key)
#      48 new_tokens = []
#
# File ~\anaconda3\lib\site-packages\unidecode\__init__.py:66, in unidecode_expect_ascii(string, errors, replace_str)
#      64 _warn_if_not_unicode(string)
#      65 try:
# ---> 66     bytestring = string.encode('ASCII')
#      67 except UnicodeEncodeError:
#      68     pass
#
# AttributeError: 'NoneType' object has no attribute 'encode'

# %%
print(len(docs_found_scopus), 'papers found on Scopus')
print(len(docs_notfound_scopus), 'papers were not found')
docs_bib_scopus = docs_found_scopus | docs_notfound_scopus
len(docs_bib_scopus)
# Out:
# 32 papers found on Scopus
# 1 papers were not found
# 33

# %%
docs_bib = docs_bib_scopus # docs_bib_scopus | docs_bib_SemanticScholar | docs_bib_CrossRef
docs_filtered = docs_bib # .filter_docs(lambda d: d.publication_year >= 1990)

# %%
index = 0
data = []
while index < len(docs_filtered):
    # re.sub('[<\[\]>]', '', str(docs_filtered[index].authors))

    authorList = []
    for author in docs_filtered[index].authors or []:
        authorList.append(author.name)

    if type(docs_filtered[index].id.doi) == type(None):
        print(docs_filtered[index].title)
        doi_paper = ''
        doi_paper_custom = ''
        # print(doi_paper)
    else:
        doi_paper = str(docs_filtered[index].id.doi) # 'https://www.doi.org/' + 
        doi_paper_custom = 'https://www.doi.org/' + str(docs_filtered[index].id.doi)
        print(doi_paper)

    data.append({'Authors': '', 'Author full names': re.sub(r'[\[\'\]]', '', str(authorList)), 'Author(s) ID': '', 
    'Title': docs_filtered[index].title, 'Year': docs_filtered[index].publication_year, 'Source title': docs_filtered[index].publication_source, 
    'Volume': '', 'Issue': '', 'Art. No.': '', 'Page start': '', 'Page end': '', 'Page count': '', 'Cited by': docs_filtered[index].citation_count, 
    'DOI': doi_paper, 'Link': doi_paper_custom,  'Affiliations': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].affiliations)), 
    'Authors with affiliations': '', 'Abstract': docs_filtered[index].abstract, 'Author Keywords': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].keywords)), 
    'Index Keywords': '', 'Molecular Sequence Numbers': '',  'Chemicals/CAS': '', 'Tradenames': '', 'Manufacturers': '', 
    'Funding Details': '', 'Funding Texts': '', 'References': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].references)), 'Correspondence Address': '', 'Editors': '', 'Publisher': docs_filtered[index].publisher, 
    'Sponsors': '', 'Conference name': '', 'Conference date': str(docs_filtered[index].publication_date), 'Conference location': '', 'Conference code': '', 'ISSN': '', 
    'ISBN': '', 'CODEN': '', 'PubMed ID': docs_filtered[index].id.pubmed, 'Language of Original Document': docs_filtered[index].language, 'Abbreviated Source Title': '', 'Document Type': docs_filtered[index].source_type, 
    'Publication Stage': '', 'Open Access': '', 'Source': '', 'EID': docs_filtered[index].id.scopusid})
    
    index += 1

# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Authors', 'Author full names', 'Author(s) ID', 
    'Title', 'Year', 'Source title', 
    'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by', 
    'DOI', 'Link',  'Affiliations', 'Authors with affiliations', 'Abstract', 'Author Keywords', 
    'Index Keywords', 'Molecular Sequence Numbers',  'Chemicals/CAS', 'Tradenames', 'Manufacturers', 
    'Funding Details', 'Funding Texts', 'References', 'Correspondence Address', 'Editors', 'Publisher', 
    'Sponsors', 'Conference name', 'Conference date', 'Conference location', 'Conference code', 'ISSN', 
    'ISBN', 'CODEN', 'PubMed ID', 'Language of Original Document', 'Abbreviated Source Title', 'Document Type', 
    'Publication Stage', 'Open Access', 'Source', 'EID'])

# Saving first group of data to a single csv file
df.to_csv('Results/' + filename + '.csv')

# Saving first group of data to a single excel file
df.to_excel('Results/' + filename_xlsx, index=False)
# Out:
# 10.1109/ACCESS.2024.3380452
# 10.3390/buildings14072207
# 10.1145/3640314
# 10.1109/ISCSIC60498.2023.00046
# 10.1109/ICIEA58696.2023.10241843
# 10.1016/j.oceaneng.2022.113479
# 10.1016/j.jag.2023.103440
# 10.1177/20552076231203672
# 10.1109/WETICE57085.2023.10477802
# 10.1145/3600160.3605070
# 10.1109/ACCESS.2022.3172964
# 10.1007/978-3-031-32515-1_7
# 10.1007/978-3-031-14844-6_7
# 10.36680/j.itcon.2022.008
# 10.1145/3517189
# 10.1145/3478680
# 10.1016/j.compind.2022.103629
# 10.1145/3569219.3569376
# 10.1145/3511616.3513098
# 10.1145/3549555.3549594
# 10.1145/3502265
# 10.1109/ACCESS.2021.3064192
# 10.1109/ISSE51541.2021.9582526
# 10.1145/3419634
# 10.1145/3450287
# 10.1145/3477244.3477985
# 10.1080/14783363.2018.1434769
# 10.1109/IEEM45057.2020.9309745
# 10.1145/3388176.3388209
# 10.1145/3386164.3387296
# 10.1115/omae2019-95152
# 10.1109/SEsCPS.2019.00012
# 10.1145/3696414

# %% [markdown]
# # Selected Paper Analysis
# Litstudy analysis

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
print(pdStatYear)

#plt.figure(1)
litstudy.plot_year_histogram(docs_filtered, vertical=True);
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_01_plot_year_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
#       Frequency
# 2019          3
# 2020          3
# 2021          5
# 2022         11
# 2023          7
# 2024          4

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
# print(pdStatYear)
pdStatYear["Journal"] = ""
pdStatYear["Conference"] = ""
pdStatYear["Workshop"] = ""
pdStatYear["Book"] = ""
pdStatYear["Symposium"] = ""
pdStatYear["Forum"] = ""
#for ind in pdStatYear.index:
#    print(pdStatYear[][ind], df['Frequency'][ind])
pdStatYear2 = pdStatYear.reset_index()
# print(pdStatYear2)
#df2 = pdStatYear2[pdStatYear2.columns[0]]
# print(pdStatYear2["index"][3])

# loop through the rows using iterrows()
for index, row in pdStatYear2.iterrows():
    # print(row['index'], row['Frequency'])
    
    docs_journal = docs_bib.filter_docs(lambda d: (d.source_type == 'Journal'  or d.id.doi == '10.1145/3696414') 
                                        and d.publication_year == row['index'])
    # print(len(docs_journal))
    pdStatYear2.loc[index,'Journal'] = len(docs_journal)
    
    pattern_conf = ['conference','symposium','lecture notes','congress','Design, Automation and Test in Europe']
    docs_conf = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                      d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                       re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE)  or
                                       re.search('studies',str(d.publication_source),re.IGNORECASE) or
                                        docs_filtered[index].id.doi == '10.1007/978-3-031-16088-2_4' or
                                        docs_filtered[index].id.doi == '10.1109/DEST.2010.5610662' or
                                       re.search('Event-Driven Interoperable Manufacturing Ecosystem for Energy Consumption Monitoring',str(docs_filtered[index].title),re.IGNORECASE) or
                                       re.search('forum',str(d.publication_source),re.IGNORECASE) ) and
                                       (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('companion',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('MODELS-C',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('ICSA-C',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Conference'] = len(docs_conf)
    
    doc_workshop = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' ) and 
                                            d.publication_year == row['index'] and 
                                            (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                            (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                             re.search('seminar',str(d.publication_source),re.IGNORECASE) or                                          
                                             re.search('2021 Design, Automation and Test in Europe Conference and Exhibition, DATE 2021',str(d.publication_source),re.IGNORECASE) or
                                             re.search('companion',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('MODELS-C',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('ICSA-C',str(d.publication_source),re.IGNORECASE) ) )
    
    # indexPP = 0
    # while indexPP < len(doc_workshop):
        # print(doc_workshop[indexPP].title)
        # print(doc_workshop[indexPP].source_type)
    #     indexPP += 1
    
    # print(len(doc_book_series))
    pdStatYear2.loc[index,'Workshop'] = len(doc_workshop)
    doc_book = docs_bib.filter_docs(lambda d: d.source_type == 'Book' and d.publication_year == row['index'])
    # print(len(doc_book))
    pdStatYear2.loc[index,'Book'] = len(doc_book)
    
    pattern_symp = ['symposium','']
    docs_symp = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569')
                                     and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                     (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                     (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Symposium'] = len(docs_symp)
                                     
    pattern_forum = ['forum','']
    docs_forum = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Forum'] = len(docs_forum)
    
#
print(pdStatYear2)
print('\n')
print('Journal:',pdStatYear2['Journal'].sum())
print('Conference:',pdStatYear2['Conference'].sum())
print('Workshop:',pdStatYear2['Workshop'].sum())
print('Book:',pdStatYear2['Book'].sum())
print('Total:',pdStatYear2['Journal'].sum()+pdStatYear2['Conference'].sum()+pdStatYear2['Workshop'].sum()+pdStatYear2['Book'].sum())
print('\n')
print('Symposium:',pdStatYear2['Symposium'].sum())
print('Forum:',pdStatYear2['Forum'].sum())
print('\n')

# plt.figure(2)
# fig, ax = plt.subplots()
pdStatYear2.plot.bar(x='index', y=['Journal','Conference','Workshop','Book'], xlabel='', stacked=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('')
plt.grid(True)

"""
plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 0/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
"""

plt.savefig('Results/' + str(filename) + '_02_plot_year_type_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
# C:\Users\vitto\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1841: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
#    index  Frequency Journal Conference Workshop Book Symposium Forum
# 0   2019          3       0          2        1    0         1     0
# 1   2020          3       1          2        0    0         0     0
# 2   2021          5       3          2        0    0         1     0
# 3   2022         11       6          4        0    0         0     0
# 4   2023          7       3          4        0    0         1     0
# 5   2024          4       4          0        0    0         0     0
#
#
# Journal: 17
# Conference: 14
# Workshop: 1
# Book: 0
# Total: 32
#
#
# Symposium: 3
# Forum: 0

# %%
import re

index = 0
while index < len(docs_filtered):
    for author in docs_filtered[index].authors or []:
        re.sub(r'[\(\[].*?[\)\]]', '', str(author.name))
    index += 1

pdStatAuthors = litstudy.stats.compute_author_histogram(docs_filtered)

pdStatAuthors
# Out:
#                                        Frequency
# Bucaioni A. (AUID: 56236820700)                2
# Renold A.P. (AUID: 46161551800)                1
# Rumpe B. (AUID: 55861872700)                   1
# Broo D.G. (AUID: 55648593700)                  1
# Feng L. (AUID: 36472925500)                    1
# ...                                          ...
# Papadonikolaki E. (AUID: 56367767700)          1
# Behnam M. (AUID: 23484086800)                  1
# Ferko E. (AUID: 57225194704)                   1
# Gkioulos V. (AUID: 57191619243)                1
# Song, Houbing                                  1
#
# [124 rows x 1 columns]

# %%
plt.figure(3)
litstudy.plot_author_histogram(docs_filtered, stacked=True, limit=35)
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_03_plot_authors_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# This names are long, which is why a short abbreviation is provided.
mapping = {
"2023 7th International Symposium on Computer Science and Intelligent Control, ISCSIC 2023": "ISCSIC (C)",
"18th IEEE Conference on Industrial Electronics and Applications, ICIEA 2023": "ICIEA",
"International Journal of Applied Earth Observation and Geoinformation": "Int. J. Appl. Earth Obs. Geoinf.",
"2023 IEEE International Conference on Enabling Technologies: Infrastructure for Collaborative Enterprises, WETICE 2023": "WETICE (C)",
"18th International Conference on Availability, Reliability and Security, ARES 2023": "ARES (C)",
"19th International Conference on Computing in Civil and Building Engineering, ICCCBE 2022": "ICCCBE (C)",
"23rd IFIP WG 5.5 Working Conference on Virtual Enterprises, PRO-VE 2022": "PRO-VE 2022",
"Journal of Information Technology in Construction": "ITcon (J)",
"25th International Academic Mindtrek Conference, Academic Mindtrek 2022": "Academic Mindtrek (C)",
"2022 Australasian Computer Science Week, ACSW 2022": "ACSW (C)",
"19th International Conference on Content-based Multimedia Indexing, CBMI 2022": "CBMI (C)",
"ACM Transactions on Internet of Things": "TIOT (J)",
"7th IEEE International Symposium on Systems Engineering, ISSE 2021": "ISSE (C)",
"21st ACM SIGBED International Conference on Embedded Software, EMSOFT 2021, held as part of the Embedded Systems Week, ESWEEK 2021": "ESWEEK (C)",
"2020 IEEE International Conference on Industrial Engineering and Engineering Management, IEEM 2020": "IEEM (C)",
"Total Quality Management and Business Excellence": "Total Qual. Manag. Bus. Excell.",
"2020 IEEE International Conference on Industrial Engineering and Engineering Management, IEEM 2020": "IEEM (C)",
"3rd International Conference on Information Science and System, ICISS 2020": "ICISS (C)",
"3rd International Symposium on Computer Science and Intelligent Control, ISCSIC 2019": "ISCSIC (C)",
"ASME 2019 38th International Conference on Ocean, Offshore and Arctic Engineering, OMAE 2019": "OMAE (C)",
"5th IEEE/ACM International Workshop on Software Engineering for Smart Cyber-Physical Systems, SEsCPS 2019": "SEsCPS (W)",
"ACM Comput. Surv.": "ACM Computing Surveys (J)"
}

# This names are long, which is why a short abbreviation is provided.
import matplotlib.transforms

# plt.figure(4)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_filtered, vertical=True, label_rotation=0, bar_width=0.6, mapper=mapping, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_04_plot_source_all_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

import csv

pdStatVenue = litstudy.stats.compute_source_histogram(docs_filtered)
display(pdStatVenue)
pdStatVenue.to_csv('Results/' + str(filename) + '_04_Venues_all.csv')
# Out:
#                                                     Frequency
# ACM Computing Surveys                                       5
# IEEE Access                                                 3
# International Symposium on Computer Science and...          2
# International Academic Mindtrek Conference Acad...          1
# IEEE ACM International Workshop on Software Eng...          1
# ASME International Conference on Ocean Offshore...          1
# International Conference on Information Science...          1
# IEEE International Conference on Industrial Eng...          1
# Total Quality Management and Business Excellence            1
# ACM SIGBED International Conference on Embedded...          1
# IEEE International Symposium on Systems Enginee...          1
# ACM Transactions on Internet of Things                      1
# International Conference on Content based Multi...          1
# Australasian Computer Science Week ACSW                     1
# Computers in Industry                                       1
# Buildings                                                   1
# Journal of Information Technology in Construction           1
# IFIP WG Working Conference on Virtual Enterpris...          1
# International Conference on Computing in Civil ...          1
# International Conference on Availability Reliab...          1
# IEEE International Conference on Enabling Techn...          1
# Digital Health                                              1
# International Journal of Applied Earth Observat...          1
# Ocean Engineering                                           1
# IEEE Conference on Industrial Electronics and A...          1
# ACM Comput Surv                                             1

# %%
docs_journal_all = docs_bib.filter_docs(lambda d: d.source_type == 'Journal'  or d.id.doi == '10.1145/3696414')
# print(len(docs_journal))

pattern_conf = ['conference','symposium','lecture notes','congress','Design, Automation and Test in Europe']
docs_conf_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                   re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE) or
                                   re.search('studies',str(d.publication_source),re.IGNORECASE) ) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('companion',str(d.publication_source),re.IGNORECASE)) )

doc_workshop_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                  d.id.doi == '10.24251/HICSS.2017.569') and  
                                        (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                        (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                         re.search('companion',str(d.publication_source),re.IGNORECASE) or
                                         re.search('forum',str(d.publication_source),re.IGNORECASE) ) )

doc_book_all = docs_bib.filter_docs(lambda d: d.source_type == 'Book')

pattern_symp = ['symposium','']
docs_symp_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )

pattern_forum = ['forum','']
docs_forum_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )

# %%
# plt.figure(5)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_conf_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_05_plot_source_conf_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(6)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_journal_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_06_plot_source_journal_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(7)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(doc_workshop_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_07_plot_source_workshop_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(8)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_symp_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_08_plot_source_symposium_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
litstudy.plot_country_histogram(docs_filtered, limit=15);

# %%
litstudy.plot_continent_histogram(docs_filtered);

# %% [markdown]
# # Selected Paper Network Analysis
# Litstudy Network analysis

# %%
################################ CITATION NETWORK ###############################################
litstudy.plot_network(litstudy.build_citation_network(docs_filtered), smooth_edges=None, max_node_size=25, min_node_size=5, file_name='Results/' + str(filename) + '_09_network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/SOTA_SECO_CPS_2024-11-14_19-47-22_09_network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/SOTA_SECO_CPS_2024-11-14_19-47-22_09_network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_full = litstudy.build_citation_network(docs_filtered)

# %%
index = 0
data = []

while index < len(bb_full.nodes):
    References = 0
    RefID = ''
    CitedBy = 0
    CitedID = ''
    
    print('Paper', index)
    print('Title:', bb_full.nodes[index].get('title'))
    print('Degree:', bb_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_full.out_edges(index))):
        edgeOut = list(bb_full.out_edges(index))[idx]
        print('Reference Paper:', edgeOut[1])
        RefID = RefID + '<' + str(edgeOut[1]) + '>'
        print('Title:', bb_full.nodes[edgeOut[1]].get('title'))
        
        References += 1
    
    print('References:', References)
    print('\n')
    
    for idx in range(len(bb_full.in_edges(index))):
        edgeIn = list(bb_full.in_edges(index))[idx]
        print('Cited by Paper:', edgeIn[0])
        CitedID = CitedID + '<' + str(edgeIn[0]) + '>'
        print(CitedID)
        print('Title:', bb_full.nodes[edgeIn[0]].get('title'))
        CitedBy += 1
    
    print('Citations:', CitedBy)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_full.nodes[index].get('title'), 'Degree': bb_full.degree[index], 'ReferencesID': RefID, 'TotRef': References, 'CitedByID': CitedID, 'TotCit': CitedBy})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper', 'Title', 'Degree', 'ReferencesID', 'TotRef', 'CitedByID', 'TotCit'])

df.to_excel('Results/' + str(filename) + '_10_CitationGraphFull.xlsx', index=False)
# Out:
# Paper 0
# Title: Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 1
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Degree: 1
#
#
# Reference Paper: 10
# Title: Architecting Digital Twins
# References: 1
#
#
# Citations: 0
#
#
# Paper 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 4
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Degree: 1
#
#
# Reference Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# References: 1
#
#
# Citations: 0
#
#
# Paper 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 4
# <4>
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Citations: 1
#
#
# Paper 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 8
# Title: Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 9
# Title: Survey on Digital Twins: From concepts to applications
# Degree: 2
#
#
# Reference Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Reference Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# References: 2
#
#
# Citations: 0
#
#
# Paper 10
# Title: Architecting Digital Twins
# Degree: 3
#
#
# Reference Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Reference Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# References: 2
#
#
# Cited by Paper: 2
# <2>
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Citations: 1
#
#
# Paper 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 19
# Title: A survey for image based methods in construction: from images to digital twins
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 22
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 23
# Title: A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 24
# Title: Event Prediction in the Big Data Era: A Systematic Survey
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 26
# Title: Leveraging system complexity for improvement
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Degree: 2
#
#
# References: 0
#
#
# Cited by Paper: 9
# <9>
# Title: Survey on Digital Twins: From concepts to applications
# Cited by Paper: 10
# <9><10>
# Title: Architecting Digital Twins
# Citations: 2
#
#
# Paper 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 10
# <10>
# Title: Architecting Digital Twins
# Citations: 1
#
#
# Paper 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 9
# <9>
# Title: Survey on Digital Twins: From concepts to applications
# Citations: 1
#
#
# Paper 32
# Title: Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0

# %%
######################################### COUPLING NETWORK ########################################
litstudy.plot_coupling_network(docs_filtered, max_edges=150, node_size=10, file_name='Results/' + str(filename) + '_11_co-network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/SOTA_SECO_CPS_2024-11-14_19-47-22_11_co-network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/SOTA_SECO_CPS_2024-11-14_19-47-22_11_co-network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# %%
coup = 0
coupID = ''
coupWeight = ''
    
index = 0
for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        print('coupID:',coupID)
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('coupWeight:',coupWeight)
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# bb_coup_full.edges
#bb_coup_full.edges(1)
# bb_coup_full.get_edge_data(70,106)

index = 0
data = []
while index < len(bb_coup_full.nodes):
    print(bb_coup_full.edges(index))
    
    coup = 0
    coupID = ''
    coupWeight = ''
    
    print('Paper', index)
    print('Title:', bb_coup_full.nodes[index].get('title'))
    print('Degree:', bb_coup_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1
        
    print('Total Coupling Papers:', coup)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_coup_full.nodes[index].get('title'), 'Degree': bb_coup_full.degree[index], 'Coupling Paper': coupID, 'Total Coupling Papers': coup, 'Weight': coupWeight})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper','Title', 'Degree', 'Coupling Paper', 'Total Coupling Papers','Weight'])

df.to_excel('Results/' + str(filename) + '_12_Co-CitationGraphFull.xlsx', index=False)
# Out:
# []
# Paper 0
# Title: Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(1, 6), (1, 7), (1, 19)]
# Paper 1
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Degree: 3
#
#
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 19
# Title: A survey for image based methods in construction: from images to digital twins
# Total Coupling Papers: 3
#
#
# [(2, 5), (2, 10), (2, 16), (2, 18), (2, 27)]
# Paper 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Degree: 5
#
#
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Total Coupling Papers: 5
#
#
# [(3, 5), (3, 9), (3, 10), (3, 11), (3, 13), (3, 14), (3, 15), (3, 17), (3, 18), (3, 21), (3, 25), (3, 28), (3, 30), (3, 31)]
# Paper 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Degree: 14
#
#
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 14
#
#
# [(4, 5), (4, 6), (4, 20)]
# Paper 4
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Degree: 3
#
#
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Total Coupling Papers: 3
#
#
# [(5, 2), (5, 3), (5, 4), (5, 6), (5, 9), (5, 10), (5, 11), (5, 13), (5, 14), (5, 15), (5, 16), (5, 17), (5, 18), (5, 20), (5, 25), (5, 27), (5, 28), (5, 30), (5, 31)]
# Paper 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Degree: 19
#
#
# Coupling Paper: 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 4
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 19
#
#
# [(6, 1), (6, 4), (6, 5), (6, 7), (6, 9), (6, 10), (6, 11), (6, 13), (6, 14), (6, 15), (6, 16), (6, 17), (6, 20), (6, 25), (6, 26), (6, 27), (6, 28), (6, 31)]
# Paper 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Degree: 18
#
#
# Coupling Paper: 1
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Coupling Paper: 4
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 26
# Title: Leveraging system complexity for improvement
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 18
#
#
# [(7, 1), (7, 6), (7, 9), (7, 10), (7, 11), (7, 13), (7, 17), (7, 20), (7, 26)]
# Paper 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Degree: 9
#
#
# Coupling Paper: 1
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 26
# Title: Leveraging system complexity for improvement
# Total Coupling Papers: 9
#
#
# []
# Paper 8
# Title: Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(9, 3), (9, 5), (9, 6), (9, 7), (9, 10), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18), (9, 20), (9, 25), (9, 26), (9, 27), (9, 28), (9, 31)]
# Paper 9
# Title: Survey on Digital Twins: From concepts to applications
# Degree: 18
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 26
# Title: Leveraging system complexity for improvement
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 18
#
#
# [(10, 2), (10, 3), (10, 5), (10, 6), (10, 7), (10, 9), (10, 12), (10, 13), (10, 14), (10, 15), (10, 16), (10, 17), (10, 18), (10, 20), (10, 21), (10, 25), (10, 27), (10, 28), (10, 29), (10, 31)]
# Paper 10
# Title: Architecting Digital Twins
# Degree: 20
#
#
# Coupling Paper: 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 20
#
#
# [(11, 3), (11, 5), (11, 6), (11, 7), (11, 12), (11, 13), (11, 14), (11, 15), (11, 16), (11, 17), (11, 27), (11, 28), (11, 30)]
# Paper 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Degree: 13
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Total Coupling Papers: 13
#
#
# [(12, 9), (12, 10), (12, 11), (12, 14), (12, 17), (12, 28)]
# Paper 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Degree: 6
#
#
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Total Coupling Papers: 6
#
#
# [(13, 3), (13, 5), (13, 6), (13, 7), (13, 9), (13, 10), (13, 11), (13, 14), (13, 15), (13, 16), (13, 17), (13, 18), (13, 21), (13, 25), (13, 27), (13, 28), (13, 29), (13, 30), (13, 31)]
# Paper 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Degree: 19
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 19
#
#
# [(14, 3), (14, 5), (14, 6), (14, 9), (14, 10), (14, 11), (14, 12), (14, 13), (14, 15), (14, 16), (14, 17), (14, 18), (14, 20), (14, 21), (14, 25), (14, 27), (14, 28), (14, 30), (14, 31)]
# Paper 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Degree: 19
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 19
#
#
# [(15, 3), (15, 5), (15, 6), (15, 9), (15, 10), (15, 11), (15, 13), (15, 14), (15, 16), (15, 17), (15, 20), (15, 21), (15, 25), (15, 27), (15, 28), (15, 29), (15, 30), (15, 31)]
# Paper 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Degree: 18
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 18
#
#
# [(16, 2), (16, 5), (16, 6), (16, 9), (16, 10), (16, 11), (16, 13), (16, 14), (16, 15), (16, 17), (16, 18), (16, 20), (16, 27), (16, 28), (16, 30), (16, 31)]
# Paper 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Degree: 16
#
#
# Coupling Paper: 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 16
#
#
# [(17, 3), (17, 5), (17, 6), (17, 7), (17, 9), (17, 10), (17, 11), (17, 12), (17, 13), (17, 14), (17, 15), (17, 16), (17, 18), (17, 20), (17, 21), (17, 25), (17, 27), (17, 28), (17, 30), (17, 31)]
# Paper 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Degree: 20
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 20
#
#
# [(18, 2), (18, 3), (18, 5), (18, 9), (18, 10), (18, 13), (18, 14), (18, 16), (18, 17), (18, 20), (18, 29)]
# Paper 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Degree: 11
#
#
# Coupling Paper: 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Total Coupling Papers: 11
#
#
# [(19, 1)]
# Paper 19
# Title: A survey for image based methods in construction: from images to digital twins
# Degree: 1
#
#
# Coupling Paper: 1
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Total Coupling Papers: 1
#
#
# [(20, 4), (20, 5), (20, 6), (20, 7), (20, 9), (20, 10), (20, 14), (20, 15), (20, 16), (20, 17), (20, 18), (20, 25), (20, 28)]
# Paper 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Degree: 13
#
#
# Coupling Paper: 4
# Title: Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Total Coupling Papers: 13
#
#
# [(21, 3), (21, 10), (21, 13), (21, 14), (21, 15), (21, 17), (21, 25), (21, 28)]
# Paper 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Degree: 8
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Total Coupling Papers: 8
#
#
# [(22, 25)]
# Paper 22
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Degree: 1
#
#
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Total Coupling Papers: 1
#
#
# []
# Paper 23
# Title: A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 24
# Title: Event Prediction in the Big Data Era: A Systematic Survey
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(25, 3), (25, 5), (25, 6), (25, 9), (25, 10), (25, 13), (25, 14), (25, 15), (25, 17), (25, 20), (25, 21), (25, 22), (25, 28)]
# Paper 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Degree: 13
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 22
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Total Coupling Papers: 13
#
#
# [(26, 6), (26, 7), (26, 9)]
# Paper 26
# Title: Leveraging system complexity for improvement
# Degree: 3
#
#
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 7
# Title: Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Total Coupling Papers: 3
#
#
# [(27, 2), (27, 5), (27, 6), (27, 9), (27, 10), (27, 11), (27, 13), (27, 14), (27, 15), (27, 16), (27, 17), (27, 28), (27, 31)]
# Paper 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Degree: 13
#
#
# Coupling Paper: 2
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 13
#
#
# [(28, 3), (28, 5), (28, 6), (28, 9), (28, 10), (28, 11), (28, 12), (28, 13), (28, 14), (28, 15), (28, 16), (28, 17), (28, 20), (28, 21), (28, 25), (28, 27), (28, 30), (28, 31)]
# Paper 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Degree: 18
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 12
# Title: Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 20
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 21
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 25
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 18
#
#
# [(29, 10), (29, 13), (29, 15), (29, 18), (29, 31)]
# Paper 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Degree: 5
#
#
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 18
# Title: Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 5
#
#
# [(30, 3), (30, 5), (30, 11), (30, 13), (30, 14), (30, 15), (30, 16), (30, 17), (30, 28), (30, 31)]
# Paper 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Degree: 10
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 11
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Total Coupling Papers: 10
#
#
# [(31, 3), (31, 5), (31, 6), (31, 9), (31, 10), (31, 13), (31, 14), (31, 15), (31, 16), (31, 17), (31, 27), (31, 28), (31, 29), (31, 30)]
# Paper 31
# Title: Reference Framework for Digital Twins within Cyber-Physical Systems
# Degree: 14
#
#
# Coupling Paper: 3
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: Digital twin for ship life-cycle: A critical systematic review
# Coupling Paper: 6
# Title: Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Coupling Paper: 9
# Title: Survey on Digital Twins: From concepts to applications
# Coupling Paper: 10
# Title: Architecting Digital Twins
# Coupling Paper: 13
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 14
# Title: Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Coupling Paper: 15
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 16
# Title: Designing solutions with the product-service systems digital twin: What is now and what is next?
# Coupling Paper: 17
# Title: HCI and Digital Twins - A Critical Look: A Literature Review
# Coupling Paper: 27
# Title: Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Coupling Paper: 28
# Title: Systematization of Digital Twins: Ontology and Conceptual Framework
# Coupling Paper: 29
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 30
# Title: On digital twin condition monitoring approach for drivetrains in marine applications
# Total Coupling Papers: 14
#
#
# []
# Paper 32
# Title: Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Degree: 0
#
#
# Total Coupling Papers: 0

# %%
################################## TOPIC MODELING ###################################
corpus = litstudy.build_corpus(docs_filtered, remove_words=['state','art','international',
          'publishing','nature','switzerland','association','computing','rights','reserved',
        'owner','author','recent','years','enable','allows','introduce','existing','identify','efficient',
        'literature','respect','update','view','achieved','assessment'], max_tokens=10000, ngram_threshold=0.0001) # custom_bigrams=custom_big

# %%
index = 0
while index < len(corpus.dictionary): 
    first_key = list(corpus.dictionary.values())[index]
    print(first_key)
    index += 1
# Out:
# advancements
# approaches
# challenges
# complex
# comprehensive
# comprehensive_survey
# cost
# cycle
# data_driven
# depends
# development
# directions
# discussed
# domain
# driven
# effective
# employed
# field
# future
# improve
# including
# learning
# management
# methods
# number
# opportunities
# optimize
# performance
# physical
# prediction
# presents
# publications
# survey
# techniques
# type
# addressed
# aim
# analysis
# conducted
# create
# enabling
# findings
# framework
# implementing
# importance
# increasing
# information
# integrated
# issues
# offering
# open
# potential
# practices
# processes
# sectors
# article
# attributes
# connected
# control
# cyber
# cyber_physical
# engineering
# evaluation
# intelligent
# level
# manufacturing
# possible
# production
# related
# relevant
# sensors
# smart
# software
# support
# systematic
# systems
# tools
# trends
# architecture
# collects
# provides
# specific
# applied
# design
# different
# dts
# life
# operation
# concept
# environment
# focus
# highlighting
# methodologies
# objects
# reference
# systematic_review
# topic
# virtual
# generally
# represent
# scientific
# attention
# emerging
# main
# services
# structure
# transformative
# case
# lack
# limitations
# shows
# solutions
# understanding
# assets
# defined
# identified
# needs
# validated
# promising
# world
# cross
# requirements
# explores
# help

# %%
len(corpus.frequencies)
# Out:
# 34

# %%
indexFREQ = 0
while indexFREQ < len(corpus.frequencies): 
    # print('Paper:',indexFREQ)
    #print('Title:',docs_filtered[indexFREQ].title)
    word_key = list(corpus.frequencies)[indexFREQ]
    index = 0
    data = []
    while index < len(word_key): 
        word = list(corpus.dictionary.values())[(word_key[index][0])]
        #print('Word:',word,' Freq:',word_key[index][1])
        data.append({'Word': word,'Freq': word_key[index][1]})
        index += 1
    
    # Saving first group of data to a single excel file
    df = pd.DataFrame(data, columns=['Word', 'Freq'])

    # Saving first group of data to a single csv file
    df.to_csv('Results/docs/' + str(indexFREQ) + '_word_freq.csv')

    # Saving first group of data to a single excel file
    #df.to_excel('Results/' + filename_xlsx, index=False)
    
    indexFREQ += 1

# %%
df_corpus = litstudy.compute_word_distribution(corpus, limit=500).filter(like='_', axis=0).sort_index()
df_corpus
df_corpus.to_csv('Results/' + str(filename) + '_13_abstract_word_freq.csv')

# %%
plt.figure(figsize=(20, 3))
litstudy.plot_word_distribution(corpus, title="Top words", limit=100, vertical=True, label_rotation=45) # limit=25,
plt.savefig('Results/' + str(filename) + '_14_plot_word_distribution_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
###################### ##################
num_topics = 15
topic_model = litstudy.train_nmf_model(corpus, num_topics, max_iter=500)

# %%
import os
if os.path.exists('Results/' + str(filename) + '_15_Topics.txt'):
    os.remove('Results/' + str(filename) + '_15_Topics.txt')

for i in range(num_topics):
    print(f'Topic {i+1}:', topic_model.best_tokens_for_topic(i), file=open('Results/' + str(filename) + '_15_Topics.txt', 'a')) # a

# %%
# Plot Topic Clouds
plt.figure(figsize=(15, 5))  # (25 topics: 25, 15), (15 Topics: 15, 5)
# litstudy.plot_topic_clouds(topic_model, ncols=5) 
litstudy.plot_topic_clouds(topic_model, ncols=5) 
plt.savefig('Results/' + str(filename) + '_16_plot_topic_clouds.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
for doc_id in topic_model.best_topic_for_documents():
    index = int(doc_id)
    print(f'Topic n. {index} for: "', docs_filtered[index].title, '"')
# Out:
# Topic n. 6 for: " Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration "
# Topic n. 9 for: " Survey on Digital Twins: From concepts to applications "
# Topic n. 13 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 3 for: " Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation "
# Topic n. 7 for: " Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review "
# Topic n. 5 for: " Digital twin for ship life-cycle: A critical systematic review "
# Topic n. 0 for: " Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles "
# Topic n. 5 for: " Digital twin for ship life-cycle: A critical systematic review "
# Topic n. 4 for: " Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey "
# Topic n. 12 for: " Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review "
# Topic n. 10 for: " Architecting Digital Twins "
# Topic n. 12 for: " Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review "
# Topic n. 14 for: " Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges "
# Topic n. 13 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 0 for: " Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles "
# Topic n. 1 for: " Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle "
# Topic n. 5 for: " Digital twin for ship life-cycle: A critical systematic review "
# Topic n. 0 for: " Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles "
# Topic n. 13 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 2 for: " Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study "
# Topic n. 11 for: " How Can Digital Twins Support the Net Zero Vision? "
# Topic n. 10 for: " Architecting Digital Twins "
# Topic n. 4 for: " Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey "
# Topic n. 14 for: " Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges "
# Topic n. 4 for: " Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey "
# Topic n. 6 for: " Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration "
# Topic n. 8 for: " Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review "
# Topic n. 2 for: " Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study "
# Topic n. 8 for: " Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review "
# Topic n. 0 for: " Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles "
# Topic n. 9 for: " Survey on Digital Twins: From concepts to applications "
# Topic n. 7 for: " Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review "
# Topic n. 13 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 3 for: " Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation "

# %%
for i in range(num_topics):
    topic_id = int(i)
    print(f'Topic n. {topic_id} for: "', topic_model.best_tokens_for_topic(topic_id), '"\n')
    for doc_id in topic_model.best_documents_for_topic(topic_id, limit=10):
        print(docs_filtered[int(doc_id)].title)
    print('\n')
# Out:
# Topic n. 0 for: " ['dts', 'level', 'specific', 'understanding', 'framework'] "
#
# HCI and Digital Twins - A Critical Look: A Literature Review
# Systematization of Digital Twins: Ontology and Conceptual Framework
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# Reference Framework for Digital Twins within Cyber-Physical Systems
# Digital twin for ship life-cycle: A critical systematic review
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
#
#
# Topic n. 1 for: " ['manufacturing', 'opportunities', 'services', 'emerging', 'development'] "
#
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Architecting Digital Twins
# Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# HCI and Digital Twins - A Critical Look: A Literature Review
#
#
# Topic n. 2 for: " ['management', 'presents', 'highlighting', 'methods', 'applications'] "
#
# A survey for image based methods in construction: from images to digital twins
# Leveraging system complexity for improvement
# A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Event Prediction in the Big Data Era: A Systematic Survey
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Digital twin for ship life-cycle: A critical systematic review
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Survey on Digital Twins: From concepts to applications
#
#
# Topic n. 3 for: " ['intelligent', 'architecture', 'trends', 'provides', 'survey'] "
#
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# Event Prediction in the Big Data Era: A Systematic Survey
# Survey on Digital Twins: From concepts to applications
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
#
#
# Topic n. 4 for: " ['prediction', 'domain', 'techniques', 'comprehensive', 'advancements'] "
#
# Event Prediction in the Big Data Era: A Systematic Survey
# Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# A Bibliometric Analysis on Model-based Systems Engineering
# Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
# Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# Survey on Digital Twins: From concepts to applications
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
#
#
# Topic n. 5 for: " ['topic', 'environment', 'virtual', 'design', 'cycle'] "
#
# Digital twin for ship life-cycle: A critical systematic review
# Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
# How Can Digital Twins Support the Net Zero Vision?
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# HCI and Digital Twins - A Critical Look: A Literature Review
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Model-driven system-performance engineering for cyber-physical systems
#
#
# Topic n. 6 for: " ['performance', 'driven', 'learning', 'techniques', 'data_driven'] "
#
# Model-driven system-performance engineering for cyber-physical systems
# Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
# Deep Learning Aided Intelligent Reflective Surfaces for 6G: A Survey
# Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# Architecting Digital Twins
# Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Event Prediction in the Big Data Era: A Systematic Survey
# Detecting latent topics and trends of digital twins in healthcare: A structural topic model-based systematic review
#
#
# Topic n. 7 for: " ['approaches', 'operation', 'discussed', 'methods', 'case'] "
#
# On digital twin condition monitoring approach for drivetrains in marine applications
# Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Digital twin for ship life-cycle: A critical systematic review
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Leveraging system complexity for improvement
#
#
# Topic n. 8 for: " ['implementing', 'processes', 'furthermore', 'enabling', 'concept'] "
#
# Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
# Predictive Maintenance Approaches in Industry 4.0: A Systematic Literature Review
# Survey on Digital Twins: From concepts to applications
# On digital twin condition monitoring approach for drivetrains in marine applications
# Digital twin for ship life-cycle: A critical systematic review
# Comprehensive Review of Machine Learning, Deep Learning, and Digital Twin Data-Driven Approaches in Battery Health Prediction of Electric Vehicles
#
#
# Topic n. 9 for: " ['framework', 'information', 'improve', 'effective', 'needs'] "
#
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Leveraging system complexity for improvement
# Reference Framework for Digital Twins within Cyber-Physical Systems
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Systematization of Digital Twins: Ontology and Conceptual Framework
# Model-driven system-performance engineering for cyber-physical systems
# A Bibliometric Analysis on Model-based Systems Engineering
# On digital twin condition monitoring approach for drivetrains in marine applications
# Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
#
#
# Topic n. 10 for: " ['architecture', 'software', 'reference', 'solutions', 'framework'] "
#
# Architecting Digital Twins
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Reference Framework for Digital Twins within Cyber-Physical Systems
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Systematization of Digital Twins: Ontology and Conceptual Framework
# Simulation Method in Automotive, Aviation and Maritime Industries for Digital Twin: A Brief Survey
# Digital twin for ship life-cycle: A critical systematic review
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
#
#
# Topic n. 11 for: " ['production', 'manufacturing', 'integrated', 'requirements', 'engineering'] "
#
# A Computer Science Perspective on Digital Transformation in Production
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Leveraging system complexity for improvement
# Systematization of Digital Twins: Ontology and Conceptual Framework
# Survey on Digital Twins: From concepts to applications
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# A Bibliometric Analysis on Model-based Systems Engineering
# Blockchain-Based Digital Twins: Research Trends, Issues, and Future Challenges
#
#
# Topic n. 12 for: " ['shows', 'concept', 'solutions', 'understanding', 'sectors'] "
#
# Survey on Digital Twins: From concepts to applications
# How Can Digital Twins Support the Net Zero Vision?
# HCI and Digital Twins - A Critical Look: A Literature Review
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Architecting Digital Twins
# A Bibliometric Analysis on Model-based Systems Engineering
# On digital twin condition monitoring approach for drivetrains in marine applications
# Model-driven system-performance engineering for cyber-physical systems
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
#
#
# Topic n. 13 for: " ['cyber', 'cyber_physical', 'level', 'physical', 'virtual'] "
#
# Study Cybersecurity of Cyber Physical System in the Virtual Environment: A Survey and New Direction
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Reference Framework for Digital Twins within Cyber-Physical Systems
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Model-driven system-performance engineering for cyber-physical systems
# Digital Twins for cities: Analyzing the gap between concepts and current implementations with a specific focus on data integration
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Systematization of Digital Twins: Ontology and Conceptual Framework
# On digital twin condition monitoring approach for drivetrains in marine applications
# Digital twin for ship life-cycle: A critical systematic review
#
#
# Topic n. 14 for: " ['smart', 'understanding', 'data_driven', 'services', 'conducted'] "
#
# Cognitive Digital Twin Enabling Smart Product-Services Systems: A Literature Review
# A Survey on IoT Big Data: Current Status, 13 V's Challenges, and Future Directions
# A Bibliometric Analysis on Model-based Systems Engineering
# Systematization of Digital Twins: Ontology and Conceptual Framework
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Designing solutions with the product-service systems digital twin: What is now and what is next?
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# How Can Digital Twins Support the Net Zero Vision?
# Enablers and barriers to the implementation of digital twins in the process industry: A systematic literature review
