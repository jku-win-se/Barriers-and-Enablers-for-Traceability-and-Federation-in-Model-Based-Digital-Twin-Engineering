# %% [markdown]
# # Multivocal Literature Review - Systematic Literature Review Data Analysis
# This notebook shows how to use litstudy from inside a Jupyter notebook. It shows how to load a dataset, plot statistics, perform topic modeling, do network analysis, and some more advanced features.
#
# This notebook focuses on the topic of federated DT.
#
# # Imports Selected Studies

# %%
# Import other libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs
import re

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
from datetime import datetime

currentDateAndTime = datetime.now()
filename = (f'MLR_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}')
filename_xlsx = (f'MLR_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}.xlsx')

print(filename)
# Out:
# MLR_2025-1-8_20-22-20

# %%
############################## LOAD Cleaned papers ###################################

# with open('AAA/studies.txt', 'r') as file:
#     data = file.read().splitlines()
#     print(data)
    
# Load csv file
docs_bib = litstudy.load_scopus_csv('Results/Selected.csv')
print(len(docs_bib), 'papers loaded from selected papers list')
# Out:
# 24 papers loaded from selected papers list

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)

docs_found_scopus, docs_notfound_scopus = litstudy.refine_scopus(docs_bib)
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 70.84it/s]

# %%
print(len(docs_found_scopus), 'papers found on Scopus')
print(len(docs_notfound_scopus), 'papers were not found')
docs_bib_scopus = docs_found_scopus | docs_notfound_scopus
len(docs_bib_scopus)
# Out:
# 24 papers found on Scopus
# 0 papers were not found
# 24

# %%
docs_bib = docs_bib_scopus # docs_bib_scopus | docs_bib_SemanticScholar | docs_bib_CrossRef
docs_filtered = docs_bib # .filter_docs(lambda d: d.publication_year >= 1990)

# %%
index = 0
data = []
while index < len(docs_filtered):
    # re.sub('[<\[\]>]', '', str(docs_filtered[index].authors))

    authorList = []
    for author in docs_filtered[index].authors or []:
        authorList.append(author.name)

    if type(docs_filtered[index].id.doi) == type(None):
        print(docs_filtered[index].title)
        doi_paper = ''
        doi_paper_custom = ''
        # print(doi_paper)
    else:
        doi_paper = str(docs_filtered[index].id.doi) # 'https://www.doi.org/' + 
        doi_paper_custom = 'https://www.doi.org/' + str(docs_filtered[index].id.doi)
        print(doi_paper)

    data.append({'Authors': '', 'Author full names': re.sub(r'[\[\'\]]', '', str(authorList)), 'Author(s) ID': '', 
    'Title': docs_filtered[index].title, 'Year': docs_filtered[index].publication_year, 'Source title': docs_filtered[index].publication_source, 
    'Volume': '', 'Issue': '', 'Art. No.': '', 'Page start': '', 'Page end': '', 'Page count': '', 'Cited by': docs_filtered[index].citation_count, 
    'DOI': doi_paper, 'Link': doi_paper_custom,  'Affiliations': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].affiliations)), 
    'Authors with affiliations': '', 'Abstract': docs_filtered[index].abstract, 'Author Keywords': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].keywords)), 
    'Index Keywords': '', 'Molecular Sequence Numbers': '',  'Chemicals/CAS': '', 'Tradenames': '', 'Manufacturers': '', 
    'Funding Details': '', 'Funding Texts': '', 'References': re.sub(r'[\[\'\]]', '', str(docs_filtered[index].references)), 'Correspondence Address': '', 'Editors': '', 'Publisher': docs_filtered[index].publisher, 
    'Sponsors': '', 'Conference name': '', 'Conference date': str(docs_filtered[index].publication_date), 'Conference location': '', 'Conference code': '', 'ISSN': '', 
    'ISBN': '', 'CODEN': '', 'PubMed ID': docs_filtered[index].id.pubmed, 'Language of Original Document': docs_filtered[index].language, 'Abbreviated Source Title': '', 'Document Type': docs_filtered[index].source_type, 
    'Publication Stage': '', 'Open Access': '', 'Source': '', 'EID': docs_filtered[index].id.scopusid})
    
    index += 1

# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Authors', 'Author full names', 'Author(s) ID', 
    'Title', 'Year', 'Source title', 
    'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by', 
    'DOI', 'Link',  'Affiliations', 'Authors with affiliations', 'Abstract', 'Author Keywords', 
    'Index Keywords', 'Molecular Sequence Numbers',  'Chemicals/CAS', 'Tradenames', 'Manufacturers', 
    'Funding Details', 'Funding Texts', 'References', 'Correspondence Address', 'Editors', 'Publisher', 
    'Sponsors', 'Conference name', 'Conference date', 'Conference location', 'Conference code', 'ISSN', 
    'ISBN', 'CODEN', 'PubMed ID', 'Language of Original Document', 'Abbreviated Source Title', 'Document Type', 
    'Publication Stage', 'Open Access', 'Source', 'EID'])

# Saving first group of data to a single csv file
df.to_csv('Results/' + filename + '.csv')

# Saving first group of data to a single excel file
df.to_excel('Results/' + filename_xlsx, index=False)
# Out:
# 10.3390/buildings14072207
# 10.1145/3640314
# 10.1109/ISCSIC60498.2023.00046
# 10.1109/ACCESS.2022.3172964
# 10.1007/978-3-031-32515-1_7
# 10.36680/j.itcon.2022.008
# 10.1145/3478680
# 10.1145/3502265
# 10.1109/ACCESS.2021.3064192
# 10.1109/ISSE51541.2021.9582526
# 10.1145/3477244.3477985
# 10.1145/3386164.3387296
# 10.1007/s10845-019-01512-w
# 10.1016/j.cirpj.2020.02.002
# 10.1109/JPROC.2020.2998530
# 10.1145/3365438.3410941
# 10.1007/s10270-019-00757-6
# 10.1109/ACCESS.2019.2953499
# 10.1109/ACCESS.2021.3060863
# 10.1109/ICISS59129.2023.10291219
# 10.3390/s24186069
# 10.3390/app14030977
# 10.1093/eurheartj/ehaa159
# 10.1109/ICSA56044.2023.00015

# %% [markdown]
# # Selected Paper Analysis
# Litstudy analysis

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
print(pdStatYear)

#plt.figure(1)
litstudy.plot_year_histogram(docs_filtered, vertical=True);
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_01_plot_year_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
#       Frequency
# 2019          2
# 2020          6
# 2021          4
# 2022          5
# 2023          3
# 2024          4

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
# print(pdStatYear)
pdStatYear["Journal"] = ""
pdStatYear["Conference"] = ""
pdStatYear["Workshop"] = ""
pdStatYear["Book"] = ""
pdStatYear["Symposium"] = ""
pdStatYear["Forum"] = ""
#for ind in pdStatYear.index:
#    print(pdStatYear[][ind], df['Frequency'][ind])
pdStatYear2 = pdStatYear.reset_index()
# print(pdStatYear2)
#df2 = pdStatYear2[pdStatYear2.columns[0]]
# print(pdStatYear2["index"][3])

# loop through the rows using iterrows()
for index, row in pdStatYear2.iterrows():
    # print(row['index'], row['Frequency'])
    
    docs_journal = docs_bib.filter_docs(lambda d: (d.source_type == 'Journal'  or d.id.doi == '10.1145/3696414') 
                                        and d.publication_year == row['index'])
    # print(len(docs_journal))
    pdStatYear2.loc[index,'Journal'] = len(docs_journal)
    
    pattern_conf = ['conference','XXX','lecture notes','congress','Design, Automation and Test in Europe']
    docs_conf = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                      d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                       re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE)  or
                                       re.search('studies',str(d.publication_source),re.IGNORECASE) or
                                        docs_filtered[index].id.doi == '10.1007/978-3-031-16088-2_4' or
                                        docs_filtered[index].id.doi == '10.1109/DEST.2010.5610662' or
                                       re.search('Event-Driven Interoperable Manufacturing Ecosystem for Energy Consumption Monitoring',str(docs_filtered[index].title),re.IGNORECASE) or
                                       re.search('forum',str(d.publication_source),re.IGNORECASE) ) and
                                       (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('companion',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('MODELS-C',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('ICSA-C',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Conference'] = len(docs_conf)
    
    doc_workshop = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' ) and 
                                            d.publication_year == row['index'] and 
                                            (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                            (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                             re.search('seminar',str(d.publication_source),re.IGNORECASE) or                                          
                                             re.search('2021 Design, Automation and Test in Europe Conference and Exhibition, DATE 2021',str(d.publication_source),re.IGNORECASE) or
                                             re.search('companion',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('MODELS-C',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('ICSA-C',str(d.publication_source),re.IGNORECASE) ) )
    
    # indexPP = 0
    # while indexPP < len(doc_workshop):
        # print(doc_workshop[indexPP].title)
        # print(doc_workshop[indexPP].source_type)
    #     indexPP += 1
    
    # print(len(doc_book_series))
    pdStatYear2.loc[index,'Workshop'] = len(doc_workshop)
    doc_book = docs_bib.filter_docs(lambda d: d.source_type == 'Book' and d.publication_year == row['index'])
    # print(len(doc_book))
    pdStatYear2.loc[index,'Book'] = len(doc_book)
    
    pattern_symp = ['symposium','']
    docs_symp = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569')
                                     and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                     (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                     (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Symposium'] = len(docs_symp)
                                     
    pattern_forum = ['forum','']
    docs_forum = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Forum'] = len(docs_forum)
    
#
print(pdStatYear2)
print('\n')
print('Journal:',pdStatYear2['Journal'].sum())
print('Conference:',pdStatYear2['Conference'].sum())
print('Symposium:',pdStatYear2['Symposium'].sum())
print('Workshop:',pdStatYear2['Workshop'].sum())
print('Book:',pdStatYear2['Book'].sum())
print('Total:',pdStatYear2['Journal'].sum()+pdStatYear2['Conference'].sum()+pdStatYear2['Workshop'].sum()+pdStatYear2['Book'].sum()+pdStatYear2['Symposium'].sum())
print('\n')
print('Forum:',pdStatYear2['Forum'].sum())
print('\n')

# plt.figure(2)
# fig, ax = plt.subplots()
pdStatYear2.plot.bar(x='index', y=['Journal','Conference','Symposium'], xlabel='', stacked=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('')
plt.grid(True)

"""
plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 0/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
"""

plt.savefig('Results/' + str(filename) + '_02_plot_year_type_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
# C:\Users\vitto\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1841: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
#    index  Frequency Journal Conference Workshop Book Symposium Forum
# 0   2019          2       1          0        0    0         1     0
# 1   2020          6       5          1        0    0         0     0
# 2   2021          4       2          1        0    0         1     0
# 3   2022          5       4          1        0    0         0     0
# 4   2023          3       0          2        0    0         1     0
# 5   2024          4       4          0        0    0         0     0
#
#
# Journal: 16
# Conference: 5
# Symposium: 3
# Workshop: 0
# Book: 0
# Total: 24
#
#
# Forum: 0

# %%
import re

index = 0
while index < len(docs_filtered):
    for author in docs_filtered[index].authors or []:
        re.sub(r'[\(\[].*?[\)\]]', '', str(author.name))
    index += 1

pdStatAuthors = litstudy.stats.compute_author_histogram(docs_filtered)

pdStatAuthors
# Out:
#                                    Frequency
# Wortmann A. (AUID: 56581745100)            3
# Bucaioni A. (AUID: 56236820700)            3
# Rumpe B. (AUID: 55861872700)               2
# Behnam M. (AUID: 23484086800)              2
# Ferko E. (AUID: 57225194704)               2
# ...                                      ...
# Feng L. (AUID: 36472925500)                1
# Kiritsis D. (AUID: 6701692247)             1
# Lu J. (AUID: 57200760675)                  1
# Wang G. (AUID: 55738687700)                1
# Pelliccione P. (AUID: 8852257900)          1
#
# [128 rows x 1 columns]

# %%
plt.figure(3)
litstudy.plot_author_histogram(docs_filtered, stacked=True, limit=35)
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_03_plot_authors_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# This names are long, which is why a short abbreviation is provided.
mapping = {
    "Buildings": "Buildings (J)",
    "ACM Comput. Surv.": "ACM Computing Surveys (J)",   
    "2023 7th International Symposium on Computer Science and Intelligent Control, ISCSIC 2023": "ISCSIC (S)",
    "IEEE Access": "IEEE Access (J)",
    "19th International Conference on Computing in Civil and Building Engineering, ICCCBE 2022": "ICCCBE (C)",
    "Journal of Information Technology in Construction": "ITcon (J)",
    "ACM Transactions on Internet of Things": "TIOT (J)",
    "7th IEEE International Symposium on Systems Engineering, ISSE 2021": "ISSE (C)",
    "21st ACM SIGBED International Conference on Embedded Software, EMSOFT 2021, held as part of the Embedded Systems Week, ESWEEK 2021": "ESWEEK (C)",
    "3rd International Symposium on Computer Science and Intelligent Control, ISCSIC 2019": "ISCSIC (S)",
    "Journal of Intelligent Manufacturing": "J. Intell. Manuf. (J)",
    "CIRP Journal of Manufacturing Science and Technology": "CIRP-JMST (J)",
    "Proceedings of the IEEE": "Proceedings of the IEEE (J)",
    "23rd ACM/IEEE International Conference on Model Driven Engineering Languages and Systems, MODELS 2020": "MODELS (C)",
    "Software and Systems Modeling": "SoSyM (J)",
    "10th International Conference on ICT for Smart Society, ICISS 2023": "ICISS (C)",
    "Sensors": "Sensors (J)",
    "Applied Sciences (Switzerland)": "Applied Sciences (J)",
    "European Heart Journal": "EHJ (J)",
    "20th IEEE International Conference on Software Architecture, ICSA 2023": "ICSA (C)"
}

# This names are long, which is why a short abbreviation is provided.
import matplotlib.transforms

# plt.figure(4)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_filtered, vertical=True, label_rotation=0, bar_width=0.6, mapper=mapping, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_04_plot_source_all_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

import csv

pdStatVenue = litstudy.stats.compute_source_histogram(docs_filtered)
display(pdStatVenue)
pdStatVenue.to_csv('Results/' + str(filename) + '_04_Venues_all.csv')
# Out:
#                                                     Frequency
# IEEE Access                                                 4
# International Symposium on Computer Science and...          2
# ACM Computing Surveys                                       2
# Buildings                                                   1
# Proceedings of the IEEE                                     1
# European Heart Journal                                      1
# Applied Sciences Switzerland                                1
# Sensors                                                     1
# International Conference on ICT for Smart Socie...          1
# Software and Systems Modeling                               1
# ACM IEEE International Conference on Model Driv...          1
# Journal of Intelligent Manufacturing                        1
# CIRP Journal of Manufacturing Science and Techn...          1
# ACM SIGBED International Conference on Embedded...          1
# IEEE International Symposium on Systems Enginee...          1
# ACM Transactions on Internet of Things                      1
# Journal of Information Technology in Construction           1
# International Conference on Computing in Civil ...          1
# IEEE International Conference on Software Archi...          1

# %%
docs_journal_all = docs_bib.filter_docs(lambda d: d.source_type == 'Journal'  or d.id.doi == '10.1145/3696414')
# print(len(docs_journal))

pattern_conf = ['conference','XXX','lecture notes','congress','Design, Automation and Test in Europe']
docs_conf_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                   re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE) or
                                   re.search('studies',str(d.publication_source),re.IGNORECASE) ) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('companion',str(d.publication_source),re.IGNORECASE)) )

doc_workshop_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                  d.id.doi == '10.24251/HICSS.2017.569') and  
                                        (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                        (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                         re.search('companion',str(d.publication_source),re.IGNORECASE) or
                                         re.search('forum',str(d.publication_source),re.IGNORECASE) ) )

doc_book_all = docs_bib.filter_docs(lambda d: d.source_type == 'Book')

pattern_symp = ['symposium','']
docs_symp_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )

pattern_forum = ['forum','']
docs_forum_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )

# %%
# plt.figure(5)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_conf_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_05_plot_source_conf_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(6)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_journal_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_06_plot_source_journal_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(8)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_symp_all, vertical=True, label_rotation=0, mapper=mapping, stacked=True);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_08_plot_source_symposium_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(8)
fig, ax = plt.subplots()
litstudy.plot_country_histogram(docs_filtered, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_08_A_plot_Country.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(8)
fig, ax = plt.subplots()
litstudy.plot_continent_histogram(docs_filtered);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_08_B_plot_Continent.png', dpi=300, bbox_inches='tight', format="PNG")

# %% [markdown]
# # Selected Paper Network Analysis
# Litstudy Network analysis

# %%
################################ CITATION NETWORK ###############################################
litstudy.plot_network(litstudy.build_citation_network(docs_filtered), smooth_edges=None, max_node_size=25, min_node_size=5, file_name='Results/' + str(filename) + '_09_network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/MLR_2025-1-8_20-22-20_09_network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/MLR_2025-1-8_20-22-20_09_network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_full = litstudy.build_citation_network(docs_filtered)

# %%
index = 0
data = []

while index < len(bb_full.nodes):
    References = 0
    RefID = ''
    CitedBy = 0
    CitedID = ''
    
    print('Paper', index)
    print('Title:', bb_full.nodes[index].get('title'))
    print('Degree:', bb_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_full.out_edges(index))):
        edgeOut = list(bb_full.out_edges(index))[idx]
        print('Reference Paper:', edgeOut[1])
        RefID = RefID + '<' + str(edgeOut[1]) + '>'
        print('Title:', bb_full.nodes[edgeOut[1]].get('title'))
        
        References += 1
    
    print('References:', References)
    print('\n')
    
    for idx in range(len(bb_full.in_edges(index))):
        edgeIn = list(bb_full.in_edges(index))[idx]
        print('Cited by Paper:', edgeIn[0])
        CitedID = CitedID + '<' + str(edgeIn[0]) + '>'
        print(CitedID)
        print('Title:', bb_full.nodes[edgeIn[0]].get('title'))
        CitedBy += 1
    
    print('Citations:', CitedBy)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_full.nodes[index].get('title'), 'Degree': bb_full.degree[index], 'ReferencesID': RefID, 'TotRef': References, 'CitedByID': CitedID, 'TotCit': CitedBy})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper', 'Title', 'Degree', 'ReferencesID', 'TotRef', 'CitedByID', 'TotCit'])

df.to_excel('Results/' + str(filename) + '_10_CitationGraphFull.xlsx', index=False)
# Out:
# Paper 0
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Degree: 2
#
#
# Reference Paper: 3
# Title: Architecting Digital Twins
# Reference Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# References: 2
#
#
# Citations: 0
#
#
# Paper 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 3
# Title: Architecting Digital Twins
# Degree: 9
#
#
# Reference Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Reference Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Reference Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Reference Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# References: 4
#
#
# Cited by Paper: 1
# <1>
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Cited by Paper: 19
# <1><19>
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Cited by Paper: 20
# <1><19><20>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Cited by Paper: 21
# <1><19><20><21>
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Cited by Paper: 23
# <1><19><20><21><23>
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Citations: 5
#
#
# Paper 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Degree: 1
#
#
# Reference Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# References: 1
#
#
# Citations: 0
#
#
# Paper 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Degree: 6
#
#
# Reference Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Reference Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Reference Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Reference Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Reference Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Reference Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# References: 6
#
#
# Citations: 0
#
#
# Paper 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 9
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 3
# <3>
# Title: Architecting Digital Twins
# Citations: 1
#
#
# Paper 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 7
# <7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Citations: 1
#
#
# Paper 13
# Title: Characterising the Digital Twin: A systematic literature review
# Degree: 2
#
#
# References: 0
#
#
# Cited by Paper: 7
# <7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Cited by Paper: 20
# <7><20>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Citations: 2
#
#
# Paper 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Degree: 4
#
#
# References: 0
#
#
# Cited by Paper: 3
# <3>
# Title: Architecting Digital Twins
# Cited by Paper: 7
# <3><7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Cited by Paper: 20
# <3><7><20>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Cited by Paper: 21
# <3><7><20><21>
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Citations: 4
#
#
# Paper 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Degree: 2
#
#
# References: 0
#
#
# Cited by Paper: 7
# <7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Cited by Paper: 21
# <7><21>
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Citations: 2
#
#
# Paper 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 7
# <7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Citations: 1
#
#
# Paper 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Degree: 4
#
#
# References: 0
#
#
# Cited by Paper: 3
# <3>
# Title: Architecting Digital Twins
# Cited by Paper: 7
# <3><7>
# Title: A Computer Science Perspective on Digital Transformation in Production
# Cited by Paper: 19
# <3><7><19>
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Cited by Paper: 20
# <3><7><19><20>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Citations: 4
#
#
# Paper 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Degree: 2
#
#
# References: 0
#
#
# Cited by Paper: 3
# <3>
# Title: Architecting Digital Twins
# Cited by Paper: 20
# <3><20>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Citations: 2
#
#
# Paper 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Degree: 2
#
#
# Reference Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Reference Paper: 3
# Title: Architecting Digital Twins
# References: 2
#
#
# Citations: 0
#
#
# Paper 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Degree: 5
#
#
# Reference Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Reference Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Reference Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Reference Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Reference Paper: 3
# Title: Architecting Digital Twins
# References: 5
#
#
# Citations: 0
#
#
# Paper 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Degree: 3
#
#
# Reference Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Reference Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Reference Paper: 3
# Title: Architecting Digital Twins
# References: 3
#
#
# Citations: 0
#
#
# Paper 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 4
# <4>
# Title: How Can Digital Twins Support the Net Zero Vision?
# Citations: 1
#
#
# Paper 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Degree: 2
#
#
# Reference Paper: 3
# Title: Architecting Digital Twins
# References: 1
#
#
# Cited by Paper: 1
# <1>
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Citations: 1

# %%
######################################### COUPLING NETWORK ########################################
litstudy.plot_coupling_network(docs_filtered, max_edges=150, node_size=10, file_name='Results/' + str(filename) + '_11_co-network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/MLR_2025-1-8_20-22-20_11_co-network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/MLR_2025-1-8_20-22-20_11_co-network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# %%
coup = 0
coupID = ''
coupWeight = ''
    
index = 0
for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        print('coupID:',coupID)
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('coupWeight:',coupWeight)
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1
# Out:
# Coupling Paper: 13
# coupID: <13>
# coupWeight: <{'weight': 1, 'score': 1}>
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 20
# coupID: <13><20>
# coupWeight: <{'weight': 1, 'score': 1}><{'weight': 1, 'score': 1}>
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# bb_coup_full.edges
#bb_coup_full.edges(1)
# bb_coup_full.get_edge_data(70,106)

index = 0
data = []
while index < len(bb_coup_full.nodes):
    print(bb_coup_full.edges(index))
    
    coup = 0
    coupID = ''
    coupWeight = ''
    
    print('Paper', index)
    print('Title:', bb_coup_full.nodes[index].get('title'))
    print('Degree:', bb_coup_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1
        
    print('Total Coupling Papers:', coup)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_coup_full.nodes[index].get('title'), 'Degree': bb_coup_full.degree[index], 'Coupling Paper': coupID, 'Total Coupling Papers': coup, 'Weight': coupWeight})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper','Title', 'Degree', 'Coupling Paper', 'Total Coupling Papers','Weight'])

df.to_excel('Results/' + str(filename) + '_12_Co-CitationGraphFull.xlsx', index=False)
# Out:
# [(0, 13), (0, 20)]
# Paper 0
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Degree: 2
#
#
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Total Coupling Papers: 2
#
#
# [(1, 3), (1, 16), (1, 17), (1, 18), (1, 19), (1, 20), (1, 21), (1, 23)]
# Paper 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Degree: 8
#
#
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 8
#
#
# [(2, 3), (2, 4), (2, 5), (2, 6), (2, 8), (2, 10), (2, 12), (2, 13), (2, 14), (2, 15), (2, 17), (2, 18), (2, 22)]
# Paper 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Degree: 13
#
#
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Total Coupling Papers: 13
#
#
# [(3, 1), (3, 2), (3, 5), (3, 6), (3, 7), (3, 8), (3, 10), (3, 11), (3, 12), (3, 13), (3, 14), (3, 15), (3, 16), (3, 17), (3, 18), (3, 19), (3, 20), (3, 21), (3, 22), (3, 23)]
# Paper 3
# Title: Architecting Digital Twins
# Degree: 20
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 20
#
#
# [(4, 2), (4, 5), (4, 6), (4, 12), (4, 13), (4, 14), (4, 15), (4, 17), (4, 18), (4, 20), (4, 21)]
# Paper 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Degree: 11
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Total Coupling Papers: 11
#
#
# [(5, 2), (5, 3), (5, 4), (5, 6), (5, 7), (5, 8), (5, 10), (5, 11), (5, 12), (5, 13), (5, 14), (5, 15), (5, 17), (5, 18), (5, 19), (5, 20), (5, 21), (5, 22), (5, 23)]
# Paper 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Degree: 19
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 19
#
#
# [(6, 2), (6, 3), (6, 4), (6, 5), (6, 7), (6, 8), (6, 10), (6, 11), (6, 12), (6, 13), (6, 14), (6, 15), (6, 17), (6, 18), (6, 20), (6, 22), (6, 23)]
# Paper 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Degree: 17
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 17
#
#
# [(7, 3), (7, 5), (7, 6), (7, 10), (7, 12), (7, 14), (7, 15), (7, 17), (7, 18), (7, 19), (7, 20), (7, 21)]
# Paper 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Degree: 12
#
#
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Total Coupling Papers: 12
#
#
# [(8, 2), (8, 3), (8, 5), (8, 6), (8, 10), (8, 12), (8, 13), (8, 14), (8, 15), (8, 17), (8, 18), (8, 22)]
# Paper 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Degree: 12
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Total Coupling Papers: 12
#
#
# [(9, 10), (9, 20)]
# Paper 9
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Degree: 2
#
#
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Total Coupling Papers: 2
#
#
# [(10, 2), (10, 3), (10, 5), (10, 6), (10, 7), (10, 8), (10, 9), (10, 12), (10, 13), (10, 14), (10, 15), (10, 17), (10, 18), (10, 20), (10, 22)]
# Paper 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Degree: 15
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 9
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Total Coupling Papers: 15
#
#
# [(11, 3), (11, 5), (11, 6), (11, 12), (11, 13), (11, 14), (11, 17), (11, 20), (11, 23)]
# Paper 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Degree: 9
#
#
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 9
#
#
# [(12, 2), (12, 3), (12, 4), (12, 5), (12, 6), (12, 7), (12, 8), (12, 10), (12, 11), (12, 13), (12, 14), (12, 15), (12, 17), (12, 18), (12, 19), (12, 20), (12, 21), (12, 22), (12, 23)]
# Paper 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Degree: 19
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 19
#
#
# [(13, 0), (13, 2), (13, 3), (13, 4), (13, 5), (13, 6), (13, 8), (13, 10), (13, 11), (13, 12), (13, 14), (13, 15), (13, 17), (13, 18), (13, 20), (13, 21), (13, 22), (13, 23)]
# Paper 13
# Title: Characterising the Digital Twin: A systematic literature review
# Degree: 18
#
#
# Coupling Paper: 0
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 18
#
#
# [(14, 2), (14, 3), (14, 4), (14, 5), (14, 6), (14, 7), (14, 8), (14, 10), (14, 11), (14, 12), (14, 13), (14, 15), (14, 17), (14, 18), (14, 20), (14, 21), (14, 22), (14, 23)]
# Paper 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Degree: 18
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 18
#
#
# [(15, 2), (15, 3), (15, 4), (15, 5), (15, 6), (15, 7), (15, 8), (15, 10), (15, 12), (15, 13), (15, 14), (15, 16), (15, 17), (15, 18), (15, 19), (15, 20), (15, 21), (15, 22)]
# Paper 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Degree: 18
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Total Coupling Papers: 18
#
#
# [(16, 1), (16, 3), (16, 15), (16, 17), (16, 18), (16, 19), (16, 20)]
# Paper 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Degree: 7
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Total Coupling Papers: 7
#
#
# [(17, 1), (17, 2), (17, 3), (17, 4), (17, 5), (17, 6), (17, 7), (17, 8), (17, 10), (17, 11), (17, 12), (17, 13), (17, 14), (17, 15), (17, 16), (17, 18), (17, 20), (17, 21), (17, 22), (17, 23)]
# Paper 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Degree: 20
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 20
#
#
# [(18, 1), (18, 2), (18, 3), (18, 4), (18, 5), (18, 6), (18, 7), (18, 8), (18, 10), (18, 12), (18, 13), (18, 14), (18, 15), (18, 16), (18, 17), (18, 19), (18, 20), (18, 21), (18, 22), (18, 23)]
# Paper 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Degree: 20
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 20
#
#
# [(19, 1), (19, 3), (19, 5), (19, 7), (19, 12), (19, 15), (19, 16), (19, 18), (19, 20), (19, 21), (19, 23)]
# Paper 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Degree: 11
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 11
#
#
# [(20, 0), (20, 1), (20, 3), (20, 4), (20, 5), (20, 6), (20, 7), (20, 9), (20, 10), (20, 11), (20, 12), (20, 13), (20, 14), (20, 15), (20, 16), (20, 17), (20, 18), (20, 19), (20, 21), (20, 23)]
# Paper 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Degree: 20
#
#
# Coupling Paper: 0
# Title: Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 9
# Title: A Bibliometric Analysis on Model-based Systems Engineering
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 16
# Title: Modeling languages in Industry 4.0: an extended systematic mapping study
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 20
#
#
# [(21, 1), (21, 3), (21, 4), (21, 5), (21, 7), (21, 12), (21, 13), (21, 14), (21, 15), (21, 17), (21, 18), (21, 19), (21, 20), (21, 23)]
# Paper 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Degree: 14
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 4
# Title: How Can Digital Twins Support the Net Zero Vision?
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 7
# Title: A Computer Science Perspective on Digital Transformation in Production
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Total Coupling Papers: 14
#
#
# [(22, 2), (22, 3), (22, 5), (22, 6), (22, 8), (22, 10), (22, 12), (22, 13), (22, 14), (22, 15), (22, 17), (22, 18)]
# Paper 22
# Title: The 'Digital Twin' to enable the vision of precision cardiology
# Degree: 12
#
#
# Coupling Paper: 2
# Title: Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 8
# Title: Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Coupling Paper: 10
# Title: Model-driven system-performance engineering for cyber-physical systems
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 15
# Title: Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Total Coupling Papers: 12
#
#
# [(23, 1), (23, 3), (23, 5), (23, 6), (23, 11), (23, 12), (23, 13), (23, 14), (23, 17), (23, 18), (23, 19), (23, 20), (23, 21)]
# Paper 23
# Title: Standardisation in Digital Twin Architectures in Manufacturing
# Degree: 13
#
#
# Coupling Paper: 1
# Title: Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Coupling Paper: 3
# Title: Architecting Digital Twins
# Coupling Paper: 5
# Title: A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Coupling Paper: 6
# Title: Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Coupling Paper: 11
# Title: Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Coupling Paper: 12
# Title: A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Coupling Paper: 13
# Title: Characterising the Digital Twin: A systematic literature review
# Coupling Paper: 14
# Title: Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Coupling Paper: 17
# Title: A survey on digital twin: Definitions, characteristics, applications, and design implications
# Coupling Paper: 18
# Title: The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Coupling Paper: 19
# Title: A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Coupling Paper: 20
# Title: Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Coupling Paper: 21
# Title: Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Total Coupling Papers: 13

# %%
################################## TOPIC MODELING ###################################
corpus = litstudy.build_corpus(docs_filtered, remove_words=['state','art','international',
          'publishing','nature','switzerland','association','computing','rights','reserved',
        'owner','author','recent','years','enable','allows','introduce','existing','identify','efficient',
        'literature','respect','update','view','achieved','assessment'], max_tokens=10000, ngram_threshold=0.0001) # custom_bigrams=custom_big

# %%
index = 0
while index < len(corpus.dictionary): 
    first_key = list(corpus.dictionary.values())[index]
    print(first_key)
    index += 1
# Out:
# address
# adoption
# aims
# comprehensive
# conducted
# decision
# decision_making
# effective
# enabling
# facilitating
# findings
# framework
# implementation
# important
# improvements
# increasing
# information
# lifecycle
# making
# methods
# potential
# processes
# publications
# sectors
# standards
# technology
# approaches
# article
# complex
# cyber
# cyber_physical
# domain
# essential
# including
# intelligent
# learning
# levels
# manufacturing
# physical
# production
# related
# relevant
# software
# support
# tools
# trends
# applications
# architecture
# collected
# complete
# driven
# management
# model_driven
# specific
# survey
# attention
# challenges
# discussed
# field
# general
# identified
# performance
# reference
# virtual
# design
# emerging
# future
# scientific
# systematic_review
# topic
# understand
# operation
# opportunities
# promising
# explore
# required
# optimize
# techniques
# areas

# %%
len(corpus.frequencies)
# Out:
# 24

# %%
indexFREQ = 0
while indexFREQ < len(corpus.frequencies): 
    # print('Paper:',indexFREQ)
    #print('Title:',docs_filtered[indexFREQ].title)
    word_key = list(corpus.frequencies)[indexFREQ]
    index = 0
    data = []
    while index < len(word_key): 
        word = list(corpus.dictionary.values())[(word_key[index][0])]
        #print('Word:',word,' Freq:',word_key[index][1])
        data.append({'Word': word,'Freq': word_key[index][1]})
        index += 1
    
    # Saving first group of data to a single excel file
    df = pd.DataFrame(data, columns=['Word', 'Freq'])

    # Saving first group of data to a single csv file
    df.to_csv('Results/docs/' + str(indexFREQ) + '_word_freq.csv')

    # Saving first group of data to a single excel file
    #df.to_excel('Results/' + filename_xlsx, index=False)
    
    indexFREQ += 1

# %%
df_corpus = litstudy.compute_word_distribution(corpus, limit=500).filter(like='_', axis=0).sort_index()
df_corpus
df_corpus.to_csv('Results/' + str(filename) + '_13_abstract_word_freq.csv')

# %%
plt.figure(figsize=(20, 3))
litstudy.plot_word_distribution(corpus, title="Top words", limit=100, vertical=True, label_rotation=45) # limit=25,
plt.savefig('Results/' + str(filename) + '_14_plot_word_distribution_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
###################### ##################
num_topics = 15
topic_model = litstudy.train_nmf_model(corpus, num_topics, max_iter=500)

# %%
import os
if os.path.exists('Results/' + str(filename) + '_15_Topics.txt'):
    os.remove('Results/' + str(filename) + '_15_Topics.txt')

for i in range(num_topics):
    print(f'Topic {i+1}:', topic_model.best_tokens_for_topic(i), file=open('Results/' + str(filename) + '_15_Topics.txt', 'a')) # a

# %%
# Plot Topic Clouds
plt.figure(figsize=(15, 5))  # (25 topics: 25, 15), (15 Topics: 15, 5)
# litstudy.plot_topic_clouds(topic_model, ncols=5) 
litstudy.plot_topic_clouds(topic_model, ncols=5) 
plt.savefig('Results/' + str(filename) + '_16_plot_topic_clouds.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
for doc_id in topic_model.best_topic_for_documents():
    index = int(doc_id)
    print(f'Topic n. {index} for: "', docs_filtered[index].title, '"')
# Out:
# Topic n. 4 for: " How Can Digital Twins Support the Net Zero Vision? "
# Topic n. 1 for: " Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study "
# Topic n. 3 for: " Architecting Digital Twins "
# Topic n. 7 for: " A Computer Science Perspective on Digital Transformation in Production "
# Topic n. 9 for: " A Bibliometric Analysis on Model-based Systems Engineering "
# Topic n. 5 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 0 for: " Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle "
# Topic n. 12 for: " A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives "
# Topic n. 8 for: " Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform "
# Topic n. 11 for: " Cloud-Based Battery Digital Twin Middleware Using Model-Based Development "
# Topic n. 14 for: " Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models "
# Topic n. 4 for: " How Can Digital Twins Support the Net Zero Vision? "
# Topic n. 1 for: " Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study "
# Topic n. 5 for: " A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION "
# Topic n. 7 for: " A Computer Science Perspective on Digital Transformation in Production "
# Topic n. 1 for: " Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study "
# Topic n. 6 for: " Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities "
# Topic n. 3 for: " Architecting Digital Twins "
# Topic n. 10 for: " Model-driven system-performance engineering for cyber-physical systems "
# Topic n. 0 for: " Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle "
# Topic n. 13 for: " Characterising the Digital Twin: A systematic literature review "
# Topic n. 7 for: " A Computer Science Perspective on Digital Transformation in Production "
# Topic n. 10 for: " Model-driven system-performance engineering for cyber-physical systems "
# Topic n. 8 for: " Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform "

# %%
for i in range(num_topics):
    topic_id = int(i)
    print(f'Topic n. {topic_id} for: "', topic_model.best_tokens_for_topic(topic_id), '"\n')
    for doc_id in topic_model.best_documents_for_topic(topic_id, limit=10):
        print(docs_filtered[int(doc_id)].title)
    print('\n')
# Out:
# Topic n. 0 for: " ['opportunities', 'technology', 'manufacturing', 'challenges', 'emerging'] "
#
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Standardisation in Digital Twin Architectures in Manufacturing
# A Computer Science Perspective on Digital Transformation in Production
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Model-driven system-performance engineering for cyber-physical systems
#
#
# Topic n. 1 for: " ['cyber_physical', 'cyber', 'physical', 'increasing', 'production'] "
#
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Model-driven system-performance engineering for cyber-physical systems
# How Can Digital Twins Support the Net Zero Vision?
# Architecting Digital Twins
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Standardisation in Digital Twin Architectures in Manufacturing
#
#
# Topic n. 2 for: " ['lifecycle', 'management', 'approaches', 'decision_making', 'making'] "
#
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# A Bibliometric Analysis on Model-based Systems Engineering
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Architecting Digital Twins
# How Can Digital Twins Support the Net Zero Vision?
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
#
#
# Topic n. 3 for: " ['intelligent', 'technology', 'applications', 'design', 'collected'] "
#
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
#
#
# Topic n. 4 for: " ['framework', 'information', 'operation', 'effective', 'processes'] "
#
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Characterising the Digital Twin: A systematic literature review
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# A Computer Science Perspective on Digital Transformation in Production
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
#
#
# Topic n. 5 for: " ['virtual', 'physical', 'applications', 'processes', 'future'] "
#
# Characterising the Digital Twin: A systematic literature review
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Architecting Digital Twins
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Modeling languages in Industry 4.0: an extended systematic mapping study
#
#
# Topic n. 6 for: " ['publications', 'cyber', 'cyber_physical', 'techniques', 'domain'] "
#
# Modeling languages in Industry 4.0: an extended systematic mapping study
# Characterising the Digital Twin: A systematic literature review
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Standardisation in Digital Twin Architectures in Manufacturing
# A Computer Science Perspective on Digital Transformation in Production
# A Bibliometric Analysis on Model-based Systems Engineering
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
#
#
# Topic n. 7 for: " ['software', 'architecture', 'applications', 'emerging', 'general'] "
#
# Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Architecting Digital Twins
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
#
#
# Topic n. 8 for: " ['architecture', 'reference', 'standards', 'general', 'including'] "
#
# Standardisation in Digital Twin Architectures in Manufacturing
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Architecting Digital Twins
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Model-driven system-performance engineering for cyber-physical systems
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# How Can Digital Twins Support the Net Zero Vision?
#
#
# Topic n. 9 for: " ['support', 'topic', 'scientific', 'aims', 'lifecycle'] "
#
# How Can Digital Twins Support the Net Zero Vision?
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# A REVIEW OF DIGITAL TWIN APPLICATIONS IN CONSTRUCTION
# Standardisation in Digital Twin Architectures in Manufacturing
# Model-driven system-performance engineering for cyber-physical systems
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Architecting Digital Twins
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# A Computer Science Perspective on Digital Transformation in Production
#
#
# Topic n. 10 for: " ['enabling', 'learning', 'increasing', 'opportunities', 'article'] "
#
# The 'Digital Twin' to enable the vision of precision cardiology
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Characterising the Digital Twin: A systematic literature review
# A Bibliometric Analysis on Model-based Systems Engineering
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
# Architecting Digital Twins
# How Can Digital Twins Support the Net Zero Vision?
#
#
# Topic n. 11 for: " ['understand', 'comprehensive', 'domain', 'aims', 'findings'] "
#
# A Bibliometric Analysis on Model-based Systems Engineering
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Modeling languages in Industry 4.0: an extended systematic mapping study
# Digital Twin in the IoT Context: A Survey on Technical Features, Scenarios, and Architectural Models
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Conceptual Framework of Information Flow Synchronization Throughout the Building Lifecycle
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# Model-driven system-performance engineering for cyber-physical systems
# A survey on digital twin: Definitions, characteristics, applications, and design implications
#
#
# Topic n. 12 for: " ['production', 'manufacturing', 'required', 'complex', 'domain'] "
#
# A Computer Science Perspective on Digital Transformation in Production
# Cloud-Based Battery Digital Twin Middleware Using Model-Based Development
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Service Computing for Industry 4.0: State of the Art, Challenges, and Research Opportunities
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Modeling languages in Industry 4.0: an extended systematic mapping study
# Standardisation in Digital Twin Architectures in Manufacturing
# A state-of-the-art survey of Digital Twin: techniques, engineering product lifecycle management and business innovation perspectives
# Characterising the Digital Twin: A systematic literature review
# A survey on digital twin: Definitions, characteristics, applications, and design implications
#
#
# Topic n. 13 for: " ['future', 'tools', 'operation', 'levels', 'areas'] "
#
# Digital Twin Approach for Operation and Maintenance of Transportation System—Systematic Review
# A Systematic Literature Review of Recent Trends and Challenges in Digital Twin Implementation
# Characterising the Digital Twin: A systematic literature review
# Standardisation in Digital Twin Architectures in Manufacturing
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Digital Twins in Software Engineering—A Systematic Literature Review and Vision
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
#
#
# Topic n. 14 for: " ['performance', 'model_driven', 'techniques', 'methods', 'areas'] "
#
# Model-driven system-performance engineering for cyber-physical systems
# The Role of AI, Machine Learning, and Big Data in Digital Twinning: A Systematic Literature Review, Challenges, and Opportunities
# Survey on Cloud Robotics Architecture and Model-Driven Reference Architecture for Decentralized Multicloud Heterogeneous-Robotics Platform
# Architecting Digital Twins
# A survey on digital twin: Definitions, characteristics, applications, and design implications
# Model-driven digital twin construction: Synthesizing the integration of cyber-physical systems with their information systems
# Standardisation in Digital Twin Architectures in Manufacturing
# A Bibliometric Analysis on Model-based Systems Engineering
# Model-based Trustworthiness Evaluation of Autonomous Cyber-Physical Production Systems: A Systematic Mapping Study
# Survey and Practice on Architecture and Deployment Method of Digital Twin System for Intelligent Substation
