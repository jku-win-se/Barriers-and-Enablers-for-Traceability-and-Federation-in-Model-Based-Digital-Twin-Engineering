# %% [markdown]
# # Multivocal Literature Review - Systematic Literature Review Data Analysis
# This notebook shows how to use litstudy from inside a Jupyter notebook. It shows how to load a dataset, plot statistics, perform topic modeling, do network analysis, and some more advanced features.
#
# This notebook focuses on the topic of federated DT.
#
# # Imports Selected Studies

# %%
# Import other libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs
import re

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
from datetime import datetime

currentDateAndTime = datetime.now()
filename = (f'SOTA_SECO_CPS_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}')
filename_xlsx = (f'SOTA_SECO_CPS_{currentDateAndTime.year}-{currentDateAndTime.month}-{currentDateAndTime.day}'
            f'_{currentDateAndTime.hour}-{currentDateAndTime.minute}-{currentDateAndTime.second}.xlsx')

print(filename)
# Out:
# SOTA_SECO_CPS_2024-10-10_12-26-0

# %%
############################## LOAD Cleaned papers ###################################

# with open('AAA/studies.txt', 'r') as file:
#     data = file.read().splitlines()
#     print(data)
    
# Load csv file
docs_bib = litstudy.load_scopus_csv('Results/SOTA_SECO_CPS_2024-10-10_11-51-20_00_Venue_OK.csv')
print(len(docs_bib), 'papers loaded from selected papers list')
# Out:
# 330 papers loaded from selected papers list

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)

docs_found_scopus, docs_notfound_scopus = litstudy.refine_scopus(docs_bib)
# Out:
#  82%|████████▏ | 272/330 [00:00<00:00, 394.90it/s]C:\Users\vitto\anaconda3\lib\site-packages\litstudy\sources\scopus.py:230: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(f"no document found for DOI {doi}: {e}")
# 100%|██████████| 330/330 [00:02<00:00, 116.40it/s]

# %%
print(len(docs_found_scopus), 'papers found on Scopus')
print(len(docs_notfound_scopus), 'papers were not found')
docs_bib_scopus = docs_found_scopus | docs_notfound_scopus
len(docs_bib_scopus)
# Out:
# 311 papers found on Scopus
# 19 papers were not found
# 330

# %%
docs_bib = docs_bib_scopus # docs_bib_scopus | docs_bib_SemanticScholar | docs_bib_CrossRef
docs_filtered = docs_bib # .filter_docs(lambda d: d.publication_year >= 1990)

# %% [markdown]
# # Selected Paper Analysis
# Litstudy analysis

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
print(pdStatYear)

#plt.figure(1)
litstudy.plot_year_histogram(docs_filtered, vertical=True);
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_01_plot_year_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
#       Frequency
# 1992          1
# 1993          0
# 1994          1
# 1995          0
# 1996          0
# 1997          1
# 1998          0
# 1999          1
# 2000          0
# 2001          1
# 2002          0
# 2003          1
# 2004          2
# 2005          0
# 2006          0
# 2007          2
# 2008          2
# 2009          4
# 2010          4
# 2011          0
# 2012          2
# 2013          3
# 2014          2
# 2015          1
# 2016          6
# 2017          5
# 2018         12
# 2019         23
# 2020         31
# 2021         35
# 2022         61
# 2023         76
# 2024         53

# %%
pdStatYear = litstudy.stats.compute_year_histogram(docs_filtered)
# print(pdStatYear)
pdStatYear["Journal"] = ""
pdStatYear["Conference"] = ""
pdStatYear["Workshop"] = ""
pdStatYear["Book"] = ""
pdStatYear["Symposium"] = ""
pdStatYear["Forum"] = ""
#for ind in pdStatYear.index:
#    print(pdStatYear[][ind], df['Frequency'][ind])
pdStatYear2 = pdStatYear.reset_index()
# print(pdStatYear2)
#df2 = pdStatYear2[pdStatYear2.columns[0]]
# print(pdStatYear2["index"][3])

# loop through the rows using iterrows()
for index, row in pdStatYear2.iterrows():
    # print(row['index'], row['Frequency'])
    
    docs_journal = docs_bib.filter_docs(lambda d: (d.source_type == 'Journal'  or d.id.doi == '10.1007/978-3-319-46508-1_13') 
                                        and d.publication_year == row['index'])
    # print(len(docs_journal))
    pdStatYear2.loc[index,'Journal'] = len(docs_journal)
    
    pattern_conf = ['conference','symposium','lecture notes','congress','Design, Automation and Test in Europe']
    docs_conf = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                      d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                       re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                       re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE)  or
                                       re.search('studies',str(d.publication_source),re.IGNORECASE) or
                                        docs_filtered[index].id.doi == '10.1007/978-3-031-16088-2_4' or
                                        docs_filtered[index].id.doi == '10.1109/DEST.2010.5610662' or
                                       re.search('Event-Driven Interoperable Manufacturing Ecosystem for Energy Consumption Monitoring',str(docs_filtered[index].title),re.IGNORECASE) or
                                       re.search('forum',str(d.publication_source),re.IGNORECASE) ) and
                                       (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('companion',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('MODELS-C',str(d.publication_source),re.IGNORECASE)) and
                                       (not re.search('ICSA-C',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Conference'] = len(docs_conf)
    
    doc_workshop = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' ) and 
                                            d.publication_year == row['index'] and 
                                            (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                            (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                             re.search('seminar',str(d.publication_source),re.IGNORECASE) or                                          
                                             re.search('2021 Design, Automation and Test in Europe Conference and Exhibition, DATE 2021',str(d.publication_source),re.IGNORECASE) or
                                             re.search('companion',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('MODELS-C',str(d.publication_source),re.IGNORECASE) or 
                                             re.search('ICSA-C',str(d.publication_source),re.IGNORECASE) ) )
    
    # indexPP = 0
    # while indexPP < len(doc_workshop):
        # print(doc_workshop[indexPP].title)
        # print(doc_workshop[indexPP].source_type)
    #     indexPP += 1
    
    # print(len(doc_book_series))
    pdStatYear2.loc[index,'Workshop'] = len(doc_workshop)
    doc_book = docs_bib.filter_docs(lambda d: d.source_type == 'Book' and d.publication_year == row['index'])
    # print(len(doc_book))
    pdStatYear2.loc[index,'Book'] = len(doc_book)
    
    pattern_symp = ['symposium','']
    docs_symp = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569')
                                     and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                     (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                     (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Symposium'] = len(docs_symp)
                                     
    pattern_forum = ['forum','']
    docs_forum = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                d.id.doi == '10.24251/HICSS.2017.569') and d.publication_year == row['index'] and
                                     (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                     re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )
    # print(len(docs_conf))  
    pdStatYear2.loc[index,'Forum'] = len(docs_forum)
    
#
print(pdStatYear2)
print('\n')
print('Journal:',pdStatYear2['Journal'].sum())
print('Conference:',pdStatYear2['Conference'].sum())
print('Workshop:',pdStatYear2['Workshop'].sum())
print('Book:',pdStatYear2['Book'].sum())
print('Total:',pdStatYear2['Journal'].sum()+pdStatYear2['Conference'].sum()+pdStatYear2['Workshop'].sum()+pdStatYear2['Book'].sum())
print('\n')
print('Symposium:',pdStatYear2['Symposium'].sum())
print('Forum:',pdStatYear2['Forum'].sum())
print('\n')

# plt.figure(2)
# fig, ax = plt.subplots()
pdStatYear2.plot.bar(x='index', y=['Journal','Conference','Workshop','Book'], xlabel='', stacked=True)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('')
plt.grid(True)

"""
plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 0/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
"""

plt.savefig('Results/' + str(filename) + '_02_plot_year_type_histogram.png', dpi=300, bbox_inches='tight', format="PNG")
# Out:
# C:\Users\vitto\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1841: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
#     index  Frequency Journal Conference Workshop Book Symposium Forum
# 0    2009          1       0          1        0    0         0     0
# 1    2010          0       0          0        0    0         0     0
# 2    2011          0       0          0        0    0         0     0
# 3    2012          0       0          0        0    0         0     0
# 4    2013          1       0          1        0    0         0     0
# 5    2014          1       0          1        0    0         0     0
# 6    2015          1       0          0        1    0         0     0
# 7    2016          2       1          1        0    0         0     0
# 8    2017          3       1          1        1    0         0     0
# 9    2018          4       2          2        0    0         0     0
# 10   2019          3       3          0        0    0         0     0
# 11   2020          1       0          1        0    0         0     0
# 12   2021          3       2          1        0    0         0     0
# 13   2022          2       1          1        0    0         1     0
# 14   2023          4       2          1        1    0         0     0
# 15   2024          2       2          0        0    0         0     0
#
#
# Journal: 14
# Conference: 11
# Workshop: 3
# Book: 0
# Total: 28
#
#
# Symposium: 1
# Forum: 0

# %%
import re

index = 0
while index < len(docs_filtered):
    for author in docs_filtered[index].authors or []:
        re.sub(r'[\(\[].*?[\)\]]', '', str(author.name))
    index += 1

pdStatAuthors = litstudy.stats.compute_author_histogram(docs_filtered)

pdStatAuthors
# Out:
#                                       Frequency
# Ruiz-Cortés A. (AUID: 15120180100)            2
# Zhang J. (AUID: 53874367300)                  1
# Weitzel B. (AUID: 55574606300)                1
# Siegel N.G. (AUID: 57204331730)               1
# Foschini L. (AUID: 7004212533)                1
# ...                                         ...
# Dolfsma W. (AUID: 55921357300)                1
# Verdouw C. (AUID: 23483245900)                1
# van Wassenaer L. (AUID: 36018110700)          1
# Wolfert S. (AUID: 37004883700)                1
# Sciarappa A. (AUID: 57835572200)              1
#
# [118 rows x 1 columns]

# %%
plt.figure(3)
litstudy.plot_author_histogram(docs_filtered, stacked=True, limit=35)
#plt.xticks(fontsize=12)
#plt.yticks(fontsize=12)
#plt.title('')
plt.grid(True)
plt.savefig('Results/' + str(filename) + '_03_plot_authors_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# This names are long, which is why a short abbreviation is provided.
import matplotlib.transforms

# plt.figure(4)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_filtered, vertical=False, label_rotation=0, bar_width=0.6, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_04_plot_source_all_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

import csv

pdStatVenue = litstudy.stats.compute_source_histogram(docs_filtered)
display(pdStatVenue)
pdStatVenue.to_csv('Results/' + str(filename) + '_04_Venues_all.csv')
# Out:
#                                                     Frequency
# Journal of Systems and Software                             3
# ACM International Conference on Aspect Oriented...          1
# Annual Conference of the IEEE Industrial Electr...          1
# International Conference on Embedded Computer S...          1
# Information and Software Technology                         1
# IEEE ACM International Workshop on Software Eng...          1
# International Conference on Software and System...          1
# European Conference on Service Oriented and Clo...          1
# Workshop on Security of Industrial Control Syst...          1
# IEEE Transactions on Network Science and Engine...          1
# International Conference on Product Focused Sof...          1
# Internet of Things Netherlands                              1
# IEEE International Conference on Cloud Computin...          1
# Symposium on Software Engineering for Adaptive ...          1
# Computing                                                   1
# International Conference on Evaluation and Asse...          1
# International Conference on Formal Methods for ...          1
# International Workshop on Control Theory for So...          1
# AI and Society                                              1
# IEEE International Conference on Industrial Cyb...          1
# Agricultural Systems                                        1
# Computer Standards and Interfaces                           1
# Future Generation Computer Systems                          1
# Land Use Policy                                             1
# IEEE Internet of Things Journal                             1
# International Journal of Innovation Studies                 1

# %%
docs_journal_all = docs_bib.filter_docs(lambda d: d.source_type == 'Journal'  or d.id.doi == '10.1007/978-3-319-46508-1_13')
# print(len(docs_journal))

pattern_conf = ['conference','symposium','lecture notes','congress','Design, Automation and Test in Europe']
docs_conf_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 ( re.search(pattern_conf[0],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[1],str(d.publication_source),re.IGNORECASE) or 
                                   re.search(pattern_conf[2],str(d.publication_source),re.IGNORECASE) or
                                   re.search(pattern_conf[4],str(d.publication_source),re.IGNORECASE) or
                                   re.search('studies',str(d.publication_source),re.IGNORECASE) ) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('companion',str(d.publication_source),re.IGNORECASE)) )

doc_workshop_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                                  d.id.doi == '10.24251/HICSS.2017.569') and  
                                        (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                        (re.search('workshop',str(d.publication_source),re.IGNORECASE) or
                                         re.search('companion',str(d.publication_source),re.IGNORECASE) or
                                         re.search('forum',str(d.publication_source),re.IGNORECASE) ) )

doc_book_all = docs_bib.filter_docs(lambda d: d.source_type == 'Book')

pattern_symp = ['symposium','']
docs_symp_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_symp[0],str(d.publication_source),re.IGNORECASE) and
                                   (not re.search('workshop',str(d.publication_source),re.IGNORECASE)) and
                                   (not re.search('conference',str(d.publication_source),re.IGNORECASE)) )

pattern_forum = ['forum','']
docs_forum_all = docs_bib.filter_docs(lambda d: (d.source_type == 'Conference Proceeding' or d.source_type == 'Book Series' or 
                                            d.id.doi == '10.24251/HICSS.2017.569') and
                                 (not d.id.doi == '10.1007/978-3-319-46508-1_13') and
                                 re.search(pattern_forum[0],str(d.publication_source),re.IGNORECASE) )

# %%
# plt.figure(5)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_conf_all, vertical=False, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_05_plot_source_conf_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(6)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_journal_all, vertical=False, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_06_plot_source_journal_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(7)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(doc_workshop_all, vertical=False, stacked=True, limit=50);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_07_plot_source_workshop_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
# plt.figure(8)
fig, ax = plt.subplots()
litstudy.plot_source_histogram(docs_symp_all, vertical=False, stacked=True, limit=25);
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('')

# rotates labels and aligns them horizontally to left 
#plt.setp( ax.xaxis.get_majorticklabels(), rotation=-90, ha="left", rotation_mode="anchor")

plt.setp( ax.xaxis.get_majorticklabels(), rotation=90) 

# Create offset transform by 5 points in x direction
dx = 5/72.; dy = 5/72. 
offset = matplotlib.transforms.ScaledTranslation(dx, dy, fig.dpi_scale_trans)

# apply offset transform to all x ticklabels.
for label in ax.xaxis.get_majorticklabels():
    label.set_transform(label.get_transform() + offset)
    
plt.savefig('Results/' + str(filename) + '_08_plot_source_symposium_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
litstudy.plot_country_histogram(docs_filtered, limit=15);

# %%
litstudy.plot_continent_histogram(docs_filtered);

# %% [markdown]
# # Selected Paper Network Analysis
# Litstudy Network analysis

# %%
################################ CITATION NETWORK ###############################################
litstudy.plot_network(litstudy.build_citation_network(docs_filtered), smooth_edges=None, max_node_size=25, min_node_size=5, file_name='Results/' + str(filename) + '_09_network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/SOTA_SECO_CPS_2024-7-24_17-41-37_09_network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/SOTA_SECO_CPS_2024-7-24_17-41-37_09_network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_full = litstudy.build_citation_network(docs_filtered)

# %%
index = 0
data = []

while index < len(bb_full.nodes):
    References = 0
    RefID = ''
    CitedBy = 0
    CitedID = ''
    
    print('Paper', index)
    print('Title:', bb_full.nodes[index].get('title'))
    print('Degree:', bb_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_full.out_edges(index))):
        edgeOut = list(bb_full.out_edges(index))[idx]
        print('Reference Paper:', edgeOut[1])
        RefID = RefID + '<' + str(edgeOut[1]) + '>'
        print('Title:', bb_full.nodes[edgeOut[1]].get('title'))
        
        References += 1
    
    print('References:', References)
    print('\n')
    
    for idx in range(len(bb_full.in_edges(index))):
        edgeIn = list(bb_full.in_edges(index))[idx]
        print('Cited by Paper:', edgeIn[0])
        CitedID = CitedID + '<' + str(edgeIn[0]) + '>'
        print(CitedID)
        print('Title:', bb_full.nodes[edgeIn[0]].get('title'))
        CitedBy += 1
    
    print('Citations:', CitedBy)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_full.nodes[index].get('title'), 'Degree': bb_full.degree[index], 'ReferencesID': RefID, 'TotRef': References, 'CitedByID': CitedID, 'TotCit': CitedBy})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper', 'Title', 'Degree', 'ReferencesID', 'TotRef', 'CitedByID', 'TotCit'])

df.to_excel('Results/' + str(filename) + '_10_CitationGraphFull.xlsx', index=False)
# Out:
# Paper 0
# Title: Modular verification of dynamically adaptive systems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 1
# Title: Automated analysis of feature models: Quo vadis?
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 2
# Title: NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 3
# Title: Automotive software engineering: A systematic mapping study
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 4
# Title: Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Degree: 1
#
#
# References: 0
#
#
# Cited by Paper: 11
# <11>
# Title: Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Citations: 1
#
#
# Paper 6
# Title: A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 7
# Title: Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 8
# Title: Digital innovation ecosystems in agri-food: design principles and organizational framework
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 9
# Title: Design of a multi-sided platform supporting CPS deployment in the automation market
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 10
# Title: Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 11
# Title: Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Degree: 1
#
#
# Reference Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# References: 1
#
#
# Citations: 0
#
#
# Paper 12
# Title: Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 13
# Title: PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 14
# Title: Software interoperability analysis in practice - A survey
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 15
# Title: From Systems to Ecosystems: Rethinking Adaptive Safety
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 16
# Title: Advantages of Arrowhead Framework for the Machine Tooling Industry
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 17
# Title: Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 18
# Title: Comprehensive assessment of open source software ecosystem health
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 19
# Title: Towards a digital ecosystem for rural areas: Experiences from three years of development
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 20
# Title: A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 21
# Title: Development of an embedded platform for secure CPS services
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 22
# Title: IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 23
# Title: The challenges of emerging software eco-systems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 24
# Title: Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 26
# Title: RISC-V Processor Technologies for Aerospace Applications in the ISOLDE Project
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0
#
#
# Paper 27
# Title: Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Degree: 0
#
#
# References: 0
#
#
# Citations: 0

# %%
######################################### COUPLING NETWORK ########################################
litstudy.plot_coupling_network(docs_filtered, max_edges=150, node_size=10, file_name='Results/' + str(filename) + '_11_co-network_full.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Results/SOTA_SECO_CPS_2024-7-24_17-41-37_11_co-network_full.html
#         <iframe
#             width="100%"
#             height="1000px"
#             src="Results/SOTA_SECO_CPS_2024-7-24_17-41-37_11_co-network_full.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# %%
coup = 0
coupID = ''
coupWeight = ''
    
index = 0
for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        print('coupID:',coupID)
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('coupWeight:',coupWeight)
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1
# Out:
# Coupling Paper: 1
# coupID: <1>
# coupWeight: <{'weight': 1, 'score': 1}>
# Title: Automated analysis of feature models: Quo vadis?

# %%
import networkx as nx

bb_coup_full = litstudy.build_coupling_network(docs_filtered, max_edges=500)

# bb_coup_full.edges
#bb_coup_full.edges(1)
# bb_coup_full.get_edge_data(70,106)

index = 0
data = []
while index < len(bb_coup_full.nodes):
    print(bb_coup_full.edges(index))
    
    coup = 0
    coupID = ''
    coupWeight = ''
    
    print('Paper', index)
    print('Title:', bb_coup_full.nodes[index].get('title'))
    print('Degree:', bb_coup_full.degree[index])
    print('\n')
    
    for idx in range(len(bb_coup_full.edges(index))):
        edgeOut = list(bb_coup_full.edges(index))[idx]
        print('Coupling Paper:', edgeOut[1])
        coupID = coupID + '<' + str(edgeOut[1]) + '>'
        coupWeight = coupWeight + '<' + str(bb_coup_full.get_edge_data(index,edgeOut[1])) + '>'
        print('Title:', bb_coup_full.nodes[edgeOut[1]].get('title'))
        coup += 1
        
    print('Total Coupling Papers:', coup)
    print('\n')
    
    data.append({'Paper': index, 'Title': bb_coup_full.nodes[index].get('title'), 'Degree': bb_coup_full.degree[index], 'Coupling Paper': coupID, 'Total Coupling Papers': coup, 'Weight': coupWeight})
        
    index += 1
    
# Saving first group of data to a single excel file
df = pd.DataFrame(data, columns=['Paper','Title', 'Degree', 'Coupling Paper', 'Total Coupling Papers','Weight'])

df.to_excel('Results/' + str(filename) + '_12_Co-CitationGraphFull.xlsx', index=False)
# Out:
# [(0, 1)]
# Paper 0
# Title: Modular verification of dynamically adaptive systems
# Degree: 1
#
#
# Coupling Paper: 1
# Title: Automated analysis of feature models: Quo vadis?
# Total Coupling Papers: 1
#
#
# [(1, 0), (1, 3), (1, 5)]
# Paper 1
# Title: Automated analysis of feature models: Quo vadis?
# Degree: 3
#
#
# Coupling Paper: 0
# Title: Modular verification of dynamically adaptive systems
# Coupling Paper: 3
# Title: Automotive software engineering: A systematic mapping study
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Total Coupling Papers: 3
#
#
# []
# Paper 2
# Title: NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(3, 1), (3, 5), (3, 15), (3, 24), (3, 25)]
# Paper 3
# Title: Automotive software engineering: A systematic mapping study
# Degree: 5
#
#
# Coupling Paper: 1
# Title: Automated analysis of feature models: Quo vadis?
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Coupling Paper: 15
# Title: From Systems to Ecosystems: Rethinking Adaptive Safety
# Coupling Paper: 24
# Title: Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Coupling Paper: 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Total Coupling Papers: 5
#
#
# []
# Paper 4
# Title: Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(5, 1), (5, 3), (5, 8), (5, 11), (5, 18), (5, 25)]
# Paper 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Degree: 6
#
#
# Coupling Paper: 1
# Title: Automated analysis of feature models: Quo vadis?
# Coupling Paper: 3
# Title: Automotive software engineering: A systematic mapping study
# Coupling Paper: 8
# Title: Digital innovation ecosystems in agri-food: design principles and organizational framework
# Coupling Paper: 11
# Title: Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Coupling Paper: 18
# Title: Comprehensive assessment of open source software ecosystem health
# Coupling Paper: 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Total Coupling Papers: 6
#
#
# [(6, 20)]
# Paper 6
# Title: A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# Degree: 1
#
#
# Coupling Paper: 20
# Title: A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Total Coupling Papers: 1
#
#
# []
# Paper 7
# Title: Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(8, 5), (8, 18), (8, 25)]
# Paper 8
# Title: Digital innovation ecosystems in agri-food: design principles and organizational framework
# Degree: 3
#
#
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Coupling Paper: 18
# Title: Comprehensive assessment of open source software ecosystem health
# Coupling Paper: 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Total Coupling Papers: 3
#
#
# [(9, 25)]
# Paper 9
# Title: Design of a multi-sided platform supporting CPS deployment in the automation market
# Degree: 1
#
#
# Coupling Paper: 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Total Coupling Papers: 1
#
#
# []
# Paper 10
# Title: Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(11, 5), (11, 18)]
# Paper 11
# Title: Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Degree: 2
#
#
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Coupling Paper: 18
# Title: Comprehensive assessment of open source software ecosystem health
# Total Coupling Papers: 2
#
#
# []
# Paper 12
# Title: Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 13
# Title: PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 14
# Title: Software interoperability analysis in practice - A survey
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(15, 3)]
# Paper 15
# Title: From Systems to Ecosystems: Rethinking Adaptive Safety
# Degree: 1
#
#
# Coupling Paper: 3
# Title: Automotive software engineering: A systematic mapping study
# Total Coupling Papers: 1
#
#
# [(16, 20)]
# Paper 16
# Title: Advantages of Arrowhead Framework for the Machine Tooling Industry
# Degree: 1
#
#
# Coupling Paper: 20
# Title: A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Total Coupling Papers: 1
#
#
# []
# Paper 17
# Title: Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(18, 5), (18, 8), (18, 11), (18, 19)]
# Paper 18
# Title: Comprehensive assessment of open source software ecosystem health
# Degree: 4
#
#
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Coupling Paper: 8
# Title: Digital innovation ecosystems in agri-food: design principles and organizational framework
# Coupling Paper: 11
# Title: Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Coupling Paper: 19
# Title: Towards a digital ecosystem for rural areas: Experiences from three years of development
# Total Coupling Papers: 4
#
#
# [(19, 18)]
# Paper 19
# Title: Towards a digital ecosystem for rural areas: Experiences from three years of development
# Degree: 1
#
#
# Coupling Paper: 18
# Title: Comprehensive assessment of open source software ecosystem health
# Total Coupling Papers: 1
#
#
# [(20, 6), (20, 16)]
# Paper 20
# Title: A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Degree: 2
#
#
# Coupling Paper: 6
# Title: A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# Coupling Paper: 16
# Title: Advantages of Arrowhead Framework for the Machine Tooling Industry
# Total Coupling Papers: 2
#
#
# []
# Paper 21
# Title: Development of an embedded platform for secure CPS services
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 22
# Title: IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 23
# Title: The challenges of emerging software eco-systems
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# [(24, 3)]
# Paper 24
# Title: Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Degree: 1
#
#
# Coupling Paper: 3
# Title: Automotive software engineering: A systematic mapping study
# Total Coupling Papers: 1
#
#
# [(25, 3), (25, 5), (25, 8), (25, 9)]
# Paper 25
# Title: Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Degree: 4
#
#
# Coupling Paper: 3
# Title: Automotive software engineering: A systematic mapping study
# Coupling Paper: 5
# Title: Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Coupling Paper: 8
# Title: Digital innovation ecosystems in agri-food: design principles and organizational framework
# Coupling Paper: 9
# Title: Design of a multi-sided platform supporting CPS deployment in the automation market
# Total Coupling Papers: 4
#
#
# []
# Paper 26
# Title: RISC-V Processor Technologies for Aerospace Applications in the ISOLDE Project
# Degree: 0
#
#
# Total Coupling Papers: 0
#
#
# []
# Paper 27
# Title: Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Degree: 0
#
#
# Total Coupling Papers: 0

# %%
################################## TOPIC MODELING ###################################
corpus = litstudy.build_corpus(docs_filtered, remove_words=['state','art','international',
          'publishing','nature','switzerland','association','computing','rights','reserved',
        'owner','author','recent','years','enable','allows','introduce','existing','identify','efficient',
        'literature','respect','update','view','achieved','assessment'], max_tokens=10000, ngram_threshold=0.0001) # custom_bigrams=custom_big

# %%
index = 0
while index < len(corpus.dictionary): 
    first_key = list(corpus.dictionary.values())[index]
    print(first_key)
    index += 1
# Out:
# address
# analyzing
# changes
# cyber
# cyber_physical
# dynamic
# environments
# includes
# increasingly
# issues
# models
# monitoring
# number
# physical
# potential
# process
# providing
# requirements
# analysis
# areas
# case
# cloud
# common
# different
# domains
# engineering
# evolution
# future
# industry
# lack
# performing
# research
# study
# systematic
# testing
# applications
# architecture
# capabilities
# communication
# control
# cps
# critical
# decision
# enabling
# internet
# internet_things
# management
# needs
# network
# resource
# run
# things
# traditional
# activities
# design
# elsevier
# important
# innovation
# multiple
# presents
# software_engineering
# structured
# actors
# collaboration
# complex
# create
# data
# digital
# information
# insights
# making
# open
# platform
# project
# smart
# technologies
# emerging
# identifies
# integration
# interaction
# users
# level
# practical
# services
# support
# business
# connected
# devices
# concepts
# objectives
# play
# role
# solutions
# technical
# value
# components
# tools
# interoperability
# opportunities
# benefits

# %%
len(corpus.frequencies)
# Out:
# 28

# %%
indexFREQ = 0
while indexFREQ < len(corpus.frequencies): 
    # print('Paper:',indexFREQ)
    #print('Title:',docs_filtered[indexFREQ].title)
    word_key = list(corpus.frequencies)[indexFREQ]
    index = 0
    data = []
    while index < len(word_key): 
        word = list(corpus.dictionary.values())[(word_key[index][0])]
        #print('Word:',word,' Freq:',word_key[index][1])
        data.append({'Word': word,'Freq': word_key[index][1]})
        index += 1
    
    # Saving first group of data to a single excel file
    df = pd.DataFrame(data, columns=['Word', 'Freq'])

    # Saving first group of data to a single csv file
    df.to_csv('Results/docs/' + str(indexFREQ) + '_word_freq.csv')

    # Saving first group of data to a single excel file
    #df.to_excel('Results/' + filename_xlsx, index=False)
    
    indexFREQ += 1

# %%
df_corpus = litstudy.compute_word_distribution(corpus, limit=500).filter(like='_', axis=0).sort_index()
df_corpus
df_corpus.to_csv('Results/' + str(filename) + '_13_abstract_word_freq.csv')

# %%
plt.figure(figsize=(20, 3))
litstudy.plot_word_distribution(corpus, title="Top words", limit=100, vertical=True, label_rotation=45) # limit=25,
plt.savefig('Results/' + str(filename) + '_14_plot_word_distribution_histogram.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
###################### ##################
num_topics = 15
topic_model = litstudy.train_nmf_model(corpus, num_topics, max_iter=500)

# %%
import os
if os.path.exists('Results/' + str(filename) + '_15_Topics.txt'):
    os.remove('Results/' + str(filename) + '_15_Topics.txt')

for i in range(num_topics):
    print(f'Topic {i+1}:', topic_model.best_tokens_for_topic(i), file=open('Results/' + str(filename) + '_15_Topics.txt', 'a')) # a

# %%
# Plot Topic Clouds
plt.figure(figsize=(15, 5))  # (25 topics: 25, 15), (15 Topics: 15, 5)
# litstudy.plot_topic_clouds(topic_model, ncols=5) 
litstudy.plot_topic_clouds(topic_model, ncols=5) 
plt.savefig('Results/' + str(filename) + '_16_plot_topic_clouds.png', dpi=300, bbox_inches='tight', format="PNG")

# %%
for doc_id in topic_model.best_topic_for_documents():
    index = int(doc_id)
    print(f'Topic n. {index} for: "', docs_filtered[index].title, '"')
# Out:
# Topic n. 11 for: " Assurance and certification of cyber–physical systems: The AMASS open source ecosystem "
# Topic n. 7 for: " Elastic systems: Towards cyber-physical ecosystems of people, processes, and things "
# Topic n. 1 for: " Automated analysis of feature models: Quo vadis? "
# Topic n. 7 for: " Elastic systems: Towards cyber-physical ecosystems of people, processes, and things "
# Topic n. 8 for: " Digital innovation ecosystems in agri-food: design principles and organizational framework "
# Topic n. 7 for: " Elastic systems: Towards cyber-physical ecosystems of people, processes, and things "
# Topic n. 12 for: " Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems "
# Topic n. 10 for: " Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems "
# Topic n. 8 for: " Digital innovation ecosystems in agri-food: design principles and organizational framework "
# Topic n. 1 for: " Automated analysis of feature models: Quo vadis? "
# Topic n. 12 for: " Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems "
# Topic n. 9 for: " Design of a multi-sided platform supporting CPS deployment in the automation market "
# Topic n. 9 for: " Design of a multi-sided platform supporting CPS deployment in the automation market "
# Topic n. 6 for: " A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments "
# Topic n. 3 for: " Automotive software engineering: A systematic mapping study "
# Topic n. 4 for: " Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence "
# Topic n. 9 for: " Design of a multi-sided platform supporting CPS deployment in the automation market "
# Topic n. 1 for: " Automated analysis of feature models: Quo vadis? "
# Topic n. 4 for: " Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence "
# Topic n. 14 for: " Software interoperability analysis in practice - A survey "
# Topic n. 5 for: " Quality assurance in software ecosystems: A systematic literature mapping and research agenda "
# Topic n. 5 for: " Quality assurance in software ecosystems: A systematic literature mapping and research agenda "
# Topic n. 12 for: " Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems "
# Topic n. 13 for: " PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems "
# Topic n. 13 for: " PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems "
# Topic n. 0 for: " Modular verification of dynamically adaptive systems "
# Topic n. 2 for: " NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV "
# Topic n. 8 for: " Digital innovation ecosystems in agri-food: design principles and organizational framework "

# %%
for i in range(num_topics):
    topic_id = int(i)
    print(f'Topic n. {topic_id} for: "', topic_model.best_tokens_for_topic(topic_id), '"\n')
    for doc_id in topic_model.best_documents_for_topic(topic_id, limit=10):
        print(docs_filtered[int(doc_id)].title)
    print('\n')
# Out:
# Topic n. 0 for: " ['collaboration', 'value', 'role', 'study', 'technical'] "
#
# Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Design of a multi-sided platform supporting CPS deployment in the automation market
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Automotive software engineering: A systematic mapping study
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
#
#
# Topic n. 1 for: " ['cps', 'services', 'network', 'support', 'platform'] "
#
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Design of a multi-sided platform supporting CPS deployment in the automation market
# Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Development of an embedded platform for secure CPS services
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Automated analysis of feature models: Quo vadis?
# Automotive software engineering: A systematic mapping study
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
#
#
# Topic n. 2 for: " ['applications', 'project', 'technologies', 'requirements', 'traditional'] "
#
# RISC-V Processor Technologies for Aerospace Applications in the ISOLDE Project
# Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Comprehensive assessment of open source software ecosystem health
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Towards a digital ecosystem for rural areas: Experiences from three years of development
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# Design of a multi-sided platform supporting CPS deployment in the automation market
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
#
#
# Topic n. 3 for: " ['interoperability', 'analysis', 'practical', 'performing', 'role'] "
#
# Software interoperability analysis in practice - A survey
# Comprehensive assessment of open source software ecosystem health
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Automated analysis of feature models: Quo vadis?
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Automotive software engineering: A systematic mapping study
#
#
# Topic n. 4 for: " ['decision', 'complex', 'level', 'number', 'support'] "
#
# From Systems to Ecosystems: Rethinking Adaptive Safety
# Comprehensive assessment of open source software ecosystem health
# Design of a multi-sided platform supporting CPS deployment in the automation market
# A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Towards a digital ecosystem for rural areas: Experiences from three years of development
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
#
#
# Topic n. 5 for: " ['devices', 'resource', 'internet', 'things', 'domains'] "
#
# A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Development of an embedded platform for secure CPS services
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
# Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
#
#
# Topic n. 6 for: " ['testing', 'support', 'engineering', 'benefits', 'multiple'] "
#
# PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Design of a multi-sided platform supporting CPS deployment in the automation market
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Automated analysis of feature models: Quo vadis?
# A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# Towards a digital ecosystem for rural areas: Experiences from three years of development
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
#
#
# Topic n. 7 for: " ['systematic', 'research', 'analysis', 'areas', 'models'] "
#
# Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# Automated analysis of feature models: Quo vadis?
# Automotive software engineering: A systematic mapping study
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# From Systems to Ecosystems: Rethinking Adaptive Safety
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
#
#
# Topic n. 8 for: " ['innovation', 'digital', 'business', 'smart', 'concepts'] "
#
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Towards a digital ecosystem for rural areas: Experiences from three years of development
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Design of a multi-sided platform supporting CPS deployment in the automation market
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Automated analysis of feature models: Quo vadis?
#
#
# Topic n. 9 for: " ['tools', 'engineering', 'industry', 'open', 'software_engineering'] "
#
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# Automotive software engineering: A systematic mapping study
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Design of a multi-sided platform supporting CPS deployment in the automation market
# PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems
# Comprehensive assessment of open source software ecosystem health
# Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
#
#
# Topic n. 10 for: " ['things', 'future', 'connected', 'process', 'integration'] "
#
# Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Comprehensive assessment of open source software ecosystem health
# Quality assurance in software ecosystems: A systematic literature mapping and research agenda
#
#
# Topic n. 11 for: " ['models', 'dynamic', 'changes', 'number', 'issues'] "
#
# Modular verification of dynamically adaptive systems
# Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Automated analysis of feature models: Quo vadis?
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Comprehensive assessment of open source software ecosystem health
# A Cloud-Based and Dynamic DNS Approach to Enable the Web of Things
# Elastic systems: Towards cyber-physical ecosystems of people, processes, and things
# Development of an embedded platform for secure CPS services
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# RISC-V Processor Technologies for Aerospace Applications in the ISOLDE Project
#
#
# Topic n. 12 for: " ['data', 'smart', 'environments', 'architecture', 'issues'] "
#
# A Real-time Linked Dataspace for the Internet of Things: Enabling “Pay-As-You-Go” Data Management in Smart Environments
# IoT-big data software ecosystems for smart cities sensing: challenges, open issues, and emerging solutions
# Internet of Things and Big Data: the disruption of the value chain and the rise of new software ecosystems
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Advantages of Arrowhead Framework for the Machine Tooling Industry
# Development of an embedded platform for secure CPS services
# Stakeholders collaborations, challenges and emerging concepts in digital twin ecosystems
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Automated analysis of feature models: Quo vadis?
#
#
# Topic n. 13 for: " ['opportunities', 'create', 'needs', 'structured', 'cyber'] "
#
# The challenges of emerging software eco-systems
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Quo vadis cyber-physical systems: Research areas of cyber-physical ecosystems
# Models@run.time for creating in-cloud dynamic cyber-physical ecosystems
# Development of an embedded platform for secure CPS services
# From Systems to Ecosystems: Rethinking Adaptive Safety
# Quality assurance in software ecosystems: A systematic literature mapping and research agenda
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# PSY-TaLiRo: A Python Toolbox for Search-Based Test Generation for Cyber-Physical Systems
#
#
# Topic n. 14 for: " ['software_engineering', 'digital', 'project', 'engineering', 'areas'] "
#
# Towards a digital ecosystem for rural areas: Experiences from three years of development
# Automotive software engineering: A systematic mapping study
# Contemporary Challenges when Developing Cyber-Physical Systems of Systems - A Case Study
# Smart systems of innovation for smart places: Challenges in deploying digital platforms for co-creation and data-intelligence
# Digital innovation ecosystems in agri-food: design principles and organizational framework
# Development of an embedded platform for secure CPS services
# Digital Transformation and Innovation and Business Ecosystems: A Bibliometric Analysis for Conceptual Insights and Collaborative Practices for Ecosystem Innovation
# Assurance and certification of cyber–physical systems: The AMASS open source ecosystem
# Automated analysis of feature models: Quo vadis?
# NLES: A novel lifetime extension scheme for safety-critical cyber-physical systems using SDN and NFV
